# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, '/Users/isabellelee/Desktop/data_science/capstone/src')

from recommend import sample_df, make_tour
from plot_rec import plot_map

# %%
world = pd.read_pickle("../data/jules_world.pkl")

# %%
tour = make_tour(world,[1,4,17])

# %%
map_ = plot_map(tour)

# %%
plt.show()

# %%
tour
# Out:
#      continent       country  \
# 1112        na        Mexico
# 818         sa         Chile
# 1602    europe        Norway
# 667     africa  South_Africa
# 1490    europe        Greece
# 1505    europe        Greece
# 700     africa      Tanzania
# 80        asia      Cambodia
# 84        asia      Cambodia
# 60     oceania   New_Zealand
#
#                                              attraction  \
# 1112           Temples of Uxmal-Uxmal Yucatan Peninsula
# 818   Museo Chileno de Arte Precolombino-Santiago Sa...
# 1602  Mount Floyen and the Funicular Floibanen-Berge...
# 667   Cape Point Nature Reserve-Cape Town Central We...
# 1490                            Parthenon-Athens Attica
# 1505                          Erechtheion-Athens Attica
# 700   Mount Kilimanjaro-Kilimanjaro National Park Ki...
# 80            Bayon Temple-Siem Reap Siem Reap Province
# 84               Choeung Ek Genocidal Center-Phnom Penh
# 60    Otago Peninsula-Dunedin Otago Region South Island
#
#                                       topicDistribution   latitude  \
# 1112  [0.00254333788894, 0.000952180338624, 0.001278...  20.362986
# 818   [0.00914921079363, 0.000699948824935, 0.003938... -33.438930
# 1602  [0.000483652597983, 0.00040467213097, 0.000339...  60.396409
# 667   [0.00096988002199, 0.00805818657835, 0.0006731... -33.940255
# 1490  [0.00349716629552, 0.00138091275711, 0.0269143...  37.968450
# 1505  [0.000968317231828, 0.000356554552623, 0.00372...  37.971860
# 700   [0.000393056283403, 0.000561666297107, 0.00810...  -3.049900
# 80    [0.000722154950546, 0.000541443306928, 0.00059...  13.440830
# 84    [0.000520061351963, 0.000404143475461, 0.00054...  11.484417
# 60    [0.0107606188376, 0.0120891998063, 0.000931172... -45.878760
#
#        longitude  lda_score
# 1112  -89.767339   0.318485
# 818   -70.652105   0.081443
# 1602    5.328565   0.317497
# 667    18.497868   0.314558
# 1490   23.728523   0.273519
# 1505   23.730475   0.270623
# 700    37.359750   0.309696
# 80    103.859038   0.324454
# 84    104.898736   0.320429
# 60    170.502798   0.304845

# %%
import output

# %%
output
# Out:
# <module 'output' from '/Users/isabellelee/Desktop/data_science/capstone/src/output.py'>
