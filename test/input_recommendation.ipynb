# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, '/Users/isabellelee/Desktop/data_science/capstone/src')

from recommend import sample_df
from plot_rec import plot_map

# %%
world = pd.read_pickle("../data/jules_world.pkl")

# %%
sample_asia, sample_africa, sample_europe, sample_na, sample_sa, sample_oceania = sample_df(world, [1,4,7])

# %%
def make_tour(sample_asia, sample_africa, sample_europe, sample_na, sample_sa, sample_oceania):
    tour = pd.DataFrame()
    tour_asia = sample_asia.sample(n=2)
    tour_africa = sample_africa.sample(n=2)
    tour_europe = sample_europe.sample(n=3)
    tour_na = sample_na.sample(n=1)
    tour_sa = sample_sa.sample(n=1)
    tour_oceania = sample_oceania.sample(n=1)
    tour = tour.append(tour_asia).append(tour_africa).append(tour_europe)\
               .append(tour_na).append(tour_sa).append(tour_oceania)
    return tour.sort_values('longitude')

# %%
tour = make_tour(sample_asia, sample_africa, sample_europe, sample_na, sample_sa, sample_oceania)

# %%
map_ = plot_map(tour)

# %%
plt.show()

# %%
tour
# Out:
#      continent       country  \
# 819         sa         Chile
# 1045        na       Curacao
# 1774    europe         Spain
# 1776    europe         Spain
# 1469    europe       Germany
# 692     africa  South_Africa
# 512     africa         Egypt
# 80        asia      Cambodia
# 88        asia      Cambodia
# 55     oceania   New_Zealand
#
#                                              attraction  \
# 819        Colchagua Museum-Santa Cruz O Higgins Region
# 1045         Dolphin Academy Curacao-Willemstad Curacao
# 1774  Bioparc Valencia-Valencia Province of Valencia...
# 1776  Oceanografic Valencia-Valencia Province of Val...
# 1469  The Holocaust Memorial Memorial to the Murdere...
# 692                   Redberry Farm-George Western Cape
# 512   Abu Simbel Temple Complex-Abu Simbel Aswan Gov...
# 80            Bayon Temple-Siem Reap Siem Reap Province
# 88    Angkor National Museum-Siem Reap Siem Reap Pro...
# 55    Toitu Otago Settlers Museum-Dunedin Otago Regi...
#
#                                       topicDistribution   latitude  \
# 819   [0.00353516050159, 0.00968981554475, 0.0026468... -34.640579
# 1045  [0.000393644975007, 0.944796685785, 0.00043127...  12.084546
# 1774  [0.000819162917997, 0.317097441298, 0.00113370...  39.478060
# 1776  [0.00114701553765, 0.852935130015, 0.001265790...  39.453006
# 1469  [0.00784849568831, 0.000706223113277, 0.000785...  52.513947
# 692   [0.00244950682262, 0.00572949548593, 0.0017400... -33.958462
# 512   [0.000459118944931, 0.575952085117, 0.00661768...  22.337232
# 80    [0.000722154950546, 0.000541443306928, 0.00059...  13.440830
# 88    [0.00167110012356, 0.000667465723207, 0.000536...  13.366573
# 55    [0.00173535545776, 0.00358938689612, 0.0010347... -45.876974
#
#        longitude  lda_score
# 819   -71.363999   0.122655
# 1045  -68.896422   0.316615
# 1774   -0.407565   0.307379
# 1776   -0.347244   0.308506
# 1469   13.378713   0.316011
# 692    22.382283   0.141024
# 512    31.625799   0.192386
# 80    103.859038   0.324389
# 88    103.860283   0.325019
# 55    170.505842   0.299137
