# %%
import requests
from bs4 import BeautifulSoup
from src.parse_funcs import soupify, rev_address, \
                        format_url, list_reviews, \
                        pgs_reviews_url, pg_urltag
import pandas as pd
import csv
import sys
reload(sys)
sys.setdefaultencoding('utf-8')

# %% [markdown]
# # Scraping Reviews

# %%
df = pd.read_csv('data/attractions.csv')

# %%
url = df.url
last_pgs = df.last_page_number

# %%
reviews_total = []
for i in range(649, len(url)):
    
    review_urls = []
    if last_pgs[i]<100:
        pgs = pg_urltag(last_pgs[i])
    else:
        pgs = pg_urltag(100)
    for x in pgs:
        review_urls.append(pgs_reviews_url(url[i], x))

    reviews_for_attraction = []  
    for x in review_urls:
        r, soup = soupify(x)
        l = list_reviews(r, soup)
        reviews_for_attraction+=l
    reviews_total.append(reviews_for_attraction)
    if i%10 ==0:
        print i
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f45341f79f47> in <module>()
#      12     reviews_for_attraction = []
#      13     for x in review_urls:
# ---> 14         r, soup = soupify(x)
#      15         l = list_reviews(r, soup)
#      16         reviews_for_attraction+=l
#
# /home/ubuntu/outrunJulesVerne/src/parse_funcs.pyc in soupify(url)
#       3
#       4 def soupify(url):
# ----> 5     r = requests.get(url)
#       6     soup = BeautifulSoup(r.content, 'html.parser', from_encoding='utf-8')
#       7     soup.prettify()
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     436                     decode_content=False,
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#     440
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     377         try:
#     378             try:  # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
#
# /home/ubuntu/anaconda/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1119
#    1120         try:
# -> 1121             response.begin()
#    1122             assert response.will_close != _UNKNOWN
#    1123             self.__state = _CS_IDLE
#
# /home/ubuntu/anaconda/lib/python2.7/httplib.pyc in begin(self)
#     436         # read until we get a non-100 response
#     437         while True:
# --> 438             version, status, reason = self._read_status()
#     439             if status != CONTINUE:
#     440                 break
#
# /home/ubuntu/anaconda/lib/python2.7/httplib.pyc in _read_status(self)
#     392     def _read_status(self):
#     393         # Initialize with Simple-Response defaults
# --> 394         line = self.fp.readline(_MAXLINE + 1)
#     395         if len(line) > _MAXLINE:
#     396             raise LineTooLong("header line")
#
# /home/ubuntu/anaconda/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:

# %%
len(reviews_total)
# Out:
# 1117

# %%
label_len = map(len,reviews_total)

# %%
attr = df.attraction

attr = [[x] for x in attr]

attr_label = []

for i in range(649, len(label_len)):
    attr_label.append(attr[i]*label_len[i])

# %%
attr_label_total = []
for x in attr_label:
    attr_label_total+=x

# %%
reviews = []
for i in range(len(reviews_total)):
    reviews += reviews_total[i]

# %%
reviews_so_far = zip(attr_label_total, reviews)

# %%
with open('data/reviews_1.csv','wb') as out:
    csv_out=csv.writer(out)
    csv_out.writerow(['attractions','reviews'])
    for row in reviews_so_far:
        csv_out.writerow(row)

# %%
pd.read_csv('data/reviews_1.csv')
# Out:
#                                               attractions  \
# 0       Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 1       Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 2       Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 3       Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 4       Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 5       Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 6       Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 7       Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 8       Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 9       Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 10      Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 11      Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 12      Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 13      Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 14      Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 15      Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 16      Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 17      Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 18      Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 19      Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 20      Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 21      Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 22      Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 23      Mara_River-Maasai_Mara_National_Reserve_Rift_V...
# 24      Tsavo_East-Tsavo_National_Park_East_Coast_Prov...
# 25      Tsavo_East-Tsavo_National_Park_East_Coast_Prov...
# 26      Tsavo_East-Tsavo_National_Park_East_Coast_Prov...
# 27      Tsavo_East-Tsavo_National_Park_East_Coast_Prov...
# 28      Tsavo_East-Tsavo_National_Park_East_Coast_Prov...
# 29      Tsavo_East-Tsavo_National_Park_East_Coast_Prov...
# ...                                                   ...
# 281814  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281815  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281816  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281817  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281818  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281819  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281820  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281821  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281822  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281823  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281824  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281825  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281826  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281827  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281828  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281829  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281830  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281831  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281832  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281833  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281834  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281835  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281836  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281837  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281838  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281839  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281840  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281841  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281842  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
# 281843  Kittiwake_Shipwreck_Artificial_Reef-West_Bay_G...
#
#                                                   reviews
# 0       \nI was so pleased with the exceptional guides...
# 1       \n.. surrounding area is breathtaking, and hip...
# 2       I was so pleased with the exceptional guides a...
# 3       .. surrounding area is breathtaking, and hipos...
# 4       Great location fantastic animals, a place to s...
# 5       Note: This is a complaint about the staff at t...
# 6       Best wild life safari\nSeen lion & cheta eatin...
# 7       The river has hippos, crocodiles and numerous ...
# 8       as part of our tour of the national reserve, w...
# 9       Loved watching the scores of animals choosing ...
# 10      This is the only place to go on safari. Saw al...
# 11      So much to see and do, I could spend days watc...
# 12      \nSpectacular, and amazing to visit with somet...
# 13      \nAmazing. Early starts and quiet cold but as ...
# 14      Spectacular, and amazing to visit with somethi...
# 15      Amazing. Early starts and quiet cold but as it...
# 16      In Sept 2017, were fortunate enough to see Wil...
# 17      The Mara is a great place. The river is specta...
# 18      such a beautiful point to watch the migration ...
# 19      Visitors go there to see the migration and it ...
# 20      Wildebeest migration is a sight to behold. Saw...
# 21      This was my second visit to the reserve. This ...
# 22      Wow! Two perfect days of wildlife viewing - th...
# 23      I headed to Kenya with immense optimism to spo...
# 24      \nThe crossing where many many wildebeests, ze...
# 25      \nSaw the top 5 animals in great abundance. Li...
# 26      The crossing where many many wildebeests, zebr...
# 27      Saw the top 5 animals in great abundance. Lion...
# 28      This was the high point of the trip that we ha...
# 29      Every inch of the Maasai Mara is unbelievably ...
# ...                                                   ...
# 281814  Fort George has beeen used by Scouts Canada fo...
# 281815  Fort George is well worth the short but sweaty...
# 281816  \nIt's a shame that the govt doesnt take care ...
# 281817  \nIt is a little bit of a hike uphill to do bu...
# 281818  It's a shame that the govt doesnt take care of...
# 281819  It is a little bit of a hike uphill to do but ...
# 281820  \nVery interesting place where you are greeted...
# 281821  \nWe went to Carib's leap last week when we vi...
# 281822  Very interesting place where you are greeted w...
# 281823  We went to Carib's leap last week when we visi...
# 281824  We visited Carib’s Leap, also known as Leapers...
# 281825  We decided to visit this memorial on a day whe...
# 281826  A bit of the island where the caribs after ris...
# 281827  The story behind this historical point is sad ...
# 281828  Stopped in on a tour and entered the cemetery....
# 281829  Grenada is a wonderful getaway. Its full of in...
# 281830  We had the Story told us but a little differen...
# 281831  At the edge of a church cemetery grounds, just...
# 281832  \nWe went on a cruise ship tour. The site has ...
# 281833  \nFortunately we were staying locally at Petit...
# 281834  We went on a cruise ship tour. The site has ea...
# 281835  Fortunately we were staying locally at Petit A...
# 281836  The story behind Carib's Leap is a interesting...
# 281837  The story about the Carib natives, and the his...
# 281838  We drove from one side of the Island to the ot...
# 281839  We had to scramble through a hole in the fence...
# 281840  Located adjacent to a cemetery this spot is ni...
# 281841  We made a quick stop (again saw cruisers here)...
# 281842  We stopped here as part of an 8 hour tour arou...
# 281843  Unfortunately the visitor centre at Carib's Le...
#
# [281844 rows x 2 columns]
