# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(0, '/Users/isabellelee/Desktop/data_science/capstone/src')

# %%
world = pd.read_pickle('../data/total_everything_world.pkl')

# %%
world[:5]
# Out:
#   continent    country                                         attraction  \
# 0   oceania  Australia              Sydney_Harbour-Sydney_New_South_Wales
# 1   oceania  Australia  Australian_War_Memorial-Canberra_Australian_Ca...
# 2   oceania  Australia  Bondi_to_Coogee_Beach_Coastal_Walk-Sydney_New_...
# 3   oceania  Australia          Sydney_Opera_House-Sydney_New_South_Wales
# 4   oceania  Australia           Shrine_of_Remembrance-Melbourne_Victoria
#
#                                    topicDistribution   latitude   longitude
# 0  [0.00663724844079, 0.00265223685009, 0.0020658... -33.868820  151.209295
# 1  [0.0116247603055, 0.000738219390953, 0.0013014... -35.279444  149.149680
# 2  [0.000906048232671, 0.00764642656688, 0.002745... -33.922393  151.255973
# 3  [0.00343066358462, 0.00205857043043, 0.0014377... -33.856536  151.214996
# 4  [0.00214805595569, 0.000721378426068, 0.001531... -37.842557  144.977767

# %%
def replace_(x):
    return x.replace('_',' ')
world['attraction'] = world.attraction.apply(replace_)

# %%
world[:5]
# Out:
#   continent    country                                         attraction  \
# 0   oceania  Australia              Sydney Harbour-Sydney New South Wales
# 1   oceania  Australia  Australian War Memorial-Canberra Australian Ca...
# 2   oceania  Australia  Bondi to Coogee Beach Coastal Walk-Sydney New ...
# 3   oceania  Australia          Sydney Opera House-Sydney New South Wales
# 4   oceania  Australia           Shrine of Remembrance-Melbourne Victoria
#
#                                    topicDistribution   latitude   longitude
# 0  [0.00663724844079, 0.00265223685009, 0.0020658... -33.868820  151.209295
# 1  [0.0116247603055, 0.000738219390953, 0.0013014... -35.279444  149.149680
# 2  [0.000906048232671, 0.00764642656688, 0.002745... -33.922393  151.255973
# 3  [0.00343066358462, 0.00205857043043, 0.0014377... -33.856536  151.214996
# 4  [0.00214805595569, 0.000721378426068, 0.001531... -37.842557  144.977767

# %%
world.to_pickle('../data/jules_world.pkl')

# %%
world[world.country == 'Panama']
# Out:
#      continent country                                         attraction  \
# 1147        na  Panama           Panama Canal-Panama City Panama Province
# 1148        na  Panama            Casco Viejo-Panama City Panama Province
# 1149        na  Panama  Miraflores Visitor Center-Panama City Panama P...
# 1150        na  Panama  Boquete Outdoor Adventures-Boquete Chiriqui Pr...
# 1151        na  Panama                   Gatun Locks-Colon Colon Province
# 1152        na  Panama        San Jose Church-Panama City Panama Province
# 1153        na  Panama       Plaza de Francia-Panama City Panama Province
# 1154        na  Panama  Cathedral at Old Panama-Panama City Panama Pro...
# 1155        na  Panama  Museo del Canal Interoceanico de Panama-Panama...
# 1156        na  Panama     Sitio Barriles Museum-Volcan Chiriqui Province
# 1157        na  Panama       Weil Art Gallery-Panama City Panama Province
# 1158        na  Panama               Biomuseo-Panama City Panama Province
# ...

# %%
_world = world.copy()
_world[_world.attraction == 'Bermejo Waterfalls-Santa Fe Veraguas Province']
# Out:
#      continent country                                     attraction  \
# 1182        na  Panama  Bermejo Waterfalls-Santa Fe Veraguas Province
#
#                                       topicDistribution  latitude  longitude
# 1182  [0.0264758370631, 0.0245090497797, 0.028760847...  31.74982 -106.48767

# %%
_world.loc[_world.attraction == 'Bermejo Waterfalls-Santa Fe Veraguas Province', 'latitude'] = 8.510642
_world.loc[_world.attraction == 'Bermejo Waterfalls-Santa Fe Veraguas Province', 'longitude'] = -81.078225

# %%
_world[_world.attraction == 'Bermejo Waterfalls-Santa Fe Veraguas Province']
# Out:
#      continent country                                     attraction  \
# 1182        na  Panama  Bermejo Waterfalls-Santa Fe Veraguas Province
#
#                                       topicDistribution  latitude  longitude
# 1182  [0.0264758370631, 0.0245090497797, 0.028760847...  8.510642 -81.078225

# %%
_world.shape
# Out:
# (1886, 6)

# %%
_world.to_pickle('../data/jules_world.pkl')
