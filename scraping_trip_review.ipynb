# %%
# import the Requests HTTP library
import requests

# import the Beautiful Soup module 
from bs4 import BeautifulSoup

# %%
r = requests.get("https://www.tripadvisor.com/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html")

# %%
soup = BeautifulSoup(r.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <link data-rup="long_lived_global_legacy" href="https://static.tacdn.com/css2/long_lived_global_legacy-v24148336985a.css" rel="stylesheet" type="text/css"/>
#   <link href="https://static.tacdn.com/favicon.ico" id="favicon" rel="icon" type="image/x-icon"/>
#   <link as="font" crossorigin="" href="https://static.tacdn.com/css2/webfonts/TripAdvisor/TripAdvisor_Regular.woff2?v003.230" rel="preload" type="font/woff2"/>
#   <link color="#00a680" href="https://static.tacdn.com/img2/icons/ta_square.svg" rel="mask-icon" sizes="any">
#    <script data-rup="global_error" type="text/javascript">
#     !function(){function e(e,n,t,r,o,i){var a={error_script:n,line:t,column:r,ready_state:document.readyState};return u?void(require.defined("ta/util/Error")&&require("ta/util/Error").record(o,"error post load:: "+e,i,a,"ERROR",{isglobal:!0})):(s.push({msg:e||"",error:o,evt:i,data:a}),!window.IS_DEBUG)}function n(){require(["ta/util/Error"],function(e){for(;s.length;){var n=s.shift();n.msg.match(/(^|[^\w.])ta .*defin/)||e.record(n.error,"window.onerror:: "+n.msg,n.evt,n.data,"ERROR",{isglobal:!0})}u=!0})}function t(){c=null,v=!1,a=d=null}function r(n,r,o,i,w,u){var s=u&&u.target;if(v){if((!a||w&&w.stack)&&(a=w),!l)try{l=arguments.callee}catch(e){}c?s=c:(!s||d&&s==window)&&(s=d),e(n,r,o,i,a,{target:s,callee:l}),t()}else{a=w,v=!0,d=s;try{l=arguments.callee}catch(e){}}}function o(e){e=e||window.event,r(e.message,e.filename,e.lineno,e.colno,e.error||e,e)}function i(e){e=e||window.event,c=e.target||e.srcElement,w&&clearTimeout(w),w=setTimeout(function(){w=0,c=null},1)}var a,d,c,l,w,u=!1,s=[],v=!1;window.onerror=function(e,n,t,o,i){return r(e,n,t,o,i,window.event),!window.IS_DEBUG},window.addEventListener?(window.addEventListener("error",o,!1),window.addEventListener("click",i,!0),window.addEventListener("load",n)):window.attachEvent&&(window.attachEvent("onerror",o),document.attachEvent("onmouseup",i),window.attachEvent("onload",n))}();!function(){var e,n,t=0,i=5e3;window.uiOverlay=function(o){document.readyState in{complete:1,loaded:1}?require(["ta/util/Error"],function(e){e.record("uiOverlay is missing from the rollup","",o)}):document.addEventListener&&(e=[].slice.call(arguments),t=(new Date).getTime(),n||(n=!0,document.addEventListener("DOMContentLoaded",function(){Date.now()-t<i&&uiOverlay.apply(null,e)},!1)))}}();
#    </script>
#    <script>
#     (function(w){
# var q={d:[],r:[],c:[],t:[],v:[]};
# var r = w.require = function() {q.r.push(arguments);};
# r.config = function() {q.c.push(arguments);};
# r.defined = r.specified = function() {return false;};
# r.taConfig = function() {q.t.push(arguments);};
# r.taVer = function(v) {q.v.push(v);};
# r.isQ=true;
# w.getRequireJSQueue = function() {return q;};
# })(window);
#    </script>
#    <script data-rup="amdearly" type="text/javascript">
#     !function(e){function t(e){return"function"==typeof require&&require.defined&&require.defined(e)}function n(e,t,n){t?e[t].apply(e,n):"function"==typeof e&&e.apply(e,n)}function r(){if(u=!0,require.isQ)throw"Fatal error - this page does not have require";if(e.getRequireJSQueue){for(var t=e.getRequireJSQueue();t.d.length>0;)define.apply(e,t.d.shift());for(;t.r.length>0;)require.apply(e,t.r.shift());e.getRequireJSQueue=null}l&&+new Date-i<5e3&&a.apply(e,l)}if(!e||!e.requireCallLast){var l,i,u=!1,a=e.requireCallLast=function(e,r){l=null;var a=[].slice.call(arguments,2);t(e)?n(require(e),r,a):t("trjs")?require(["trjs!"+e],function(e){n(e,r,a)}):u||(i=+new Date,l=[].slice.call(arguments))},c=e.requireCallIfReady=function(n){t(n)&&a.apply(e,arguments)},o=function(t,n,r,l){var i=c;return!r||"click"!==r.type&&"submit"!==r.type||(i=a,r.preventDefault&&r.preventDefault()),l.unshift(n),l.unshift(t),i.apply(e,l),!1};e.remoteModule=function(e,t){return o("remoteModule",null,e,[].slice.call(arguments))},e.requireEvCall=function(e,t,n,r){return e=e.match(/^((?:[^\/]+\/)*[^\/\.]+)\.([^\/]*)?$/),o(e[1],e[2],t,[].slice.call(arguments,1))},e.widgetEvCall=function(e,t,n,r){return o("ta/prwidgets","call",t,[].slice.call(arguments))},e.placementEvCall=function(e,t,n,r,l){return o("ta/p13n/placements","evCall",n,[].slice.call(arguments))},document.addEventListener?document.addEventListener("DOMContentLoaded",r):e.addEventListener?e.addEventListener("load",r):e.attachEvent&&e.attachEvent("onload",r)}}(window);
#    </script>
#    <meta content="no" http-equiv="imagetoolbar"/>
#    <title>
#     Burj Khalifa (Dubai, United Arab Emirates): Top Tips Before You Go (with Photos) - TripAdvisor
#    </title>
#    <script type="application/ld+json">
#     {
# "@context" : "http://schema.org",
# "@type" : "LocalBusiness",
# "name" : "Burj Khalifa",
# "url" : "/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html",
# "image" : "https://media-cdn.tripadvisor.com/media/photo-s/0d/fc/4c/03/burj-khalifa.jpg",
# "aggregateRating" : {
# "@type" : "AggregateRating",
# "ratingValue" : "4.5",
# "reviewCount" : "53818"
# },
# "address" : {
# "@type" : "PostalAddress",
# "streetAddress" : "1 Mohammed Bin Rashid Boulevard Downtown Dubai",
# "addressLocality" : "Dubai",
# "addressRegion" : "Emirate of Dubai",
# "postalCode" : "9440",
# "addressCountry" : {
# "@type" : "Country",
# "name" : "United Arab Emirates"
# }
# }
# }
#    </script>
#    <meta content="no-cache" http-equiv="pragma"/>
#    <meta content="no-cache,must-revalidate" http-equiv="cache-control"/>
#    <meta content="0" http-equiv="expires"/>
#    <meta content="Burj Khalifa (Dubai, United Arab Emirates): Top Tips Before You Go (with Photos) - TripAdvisor" property="og:title"/>
#    <meta content="Book your tickets online for Burj Khalifa, Dubai: See 53,818 reviews, articles, and 31,529 photos of Burj Khalifa, ranked No.2 on TripAdvisor among 411 attractions in Dubai." property="og:description"/>
#    <meta content="https://media-cdn.tripadvisor.com/media/photo-s/0d/fc/4c/03/burj-khalifa.jpg" property="og:image"/>
#    <meta content="550" property="og:image:width"/>
#    <meta content="386" property="og:image:height"/>
#    <meta content="5863091683" property="fb:pages"/>
#    <meta content="329182043776593" property="fb:pages"/>
#    <meta content="Burj Khalifa, Dubai, Emirate of Dubai, attractions, things to do, attraction, opinions, fun, opening, map, reviews, information, guidebooks, advice, popular" name="keywords">
#     <meta content="Book your tickets online for Burj Khalifa, Dubai: See 53,818 reviews, articles, and 31,529 photos of Burj Khalifa, ranked No.2 on TripAdvisor among 411 attractions in Dubai." name="description">
#      <link href="https://www.tripadvisor.com/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="en" rel="alternate"/>
#      <link href="https://www.tripadvisor.co.uk/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="en-GB" rel="alternate"/>
#      <link href="https://www.tripadvisor.ca/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="en-CA" rel="alternate"/>
#      <link href="https://fr.tripadvisor.ca/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="fr-CA" rel="alternate"/>
#      <link href="https://www.tripadvisor.it/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="it" rel="alternate"/>
#      <link href="https://www.tripadvisor.es/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="es" rel="alternate"/>
#      <link href="https://www.tripadvisor.de/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="de" rel="alternate"/>
#      <link href="https://www.tripadvisor.fr/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="fr" rel="alternate"/>
#      <link href="https://www.tripadvisor.jp/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="ja" rel="alternate"/>
#      <link href="https://cn.tripadvisor.com/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="zh-Hans" rel="alternate"/>
#      <link href="https://www.tripadvisor.in/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="en-IN" rel="alternate"/>
#      <link href="https://www.tripadvisor.se/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="sv" rel="alternate"/>
#      <link href="https://www.tripadvisor.nl/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="nl" rel="alternate"/>
#      <link href="https://www.tripadvisor.com.br/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="pt" rel="alternate"/>
#      <link href="https://www.tripadvisor.com.tr/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="tr" rel="alternate"/>
#      <link href="https://www.tripadvisor.dk/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="da" rel="alternate"/>
#      <link href="https://www.tripadvisor.com.mx/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="es-MX" rel="alternate"/>
#      <link href="https://www.tripadvisor.ie/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="en-IE" rel="alternate"/>
#      <link href="https://ar.tripadvisor.com/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="ar" rel="alternate"/>
#      <link href="https://www.tripadvisor.com.eg/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="ar-EG" rel="alternate"/>
#      <link href="https://www.tripadvisor.cz/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="cs" rel="alternate"/>
#      <link href="https://www.tripadvisor.at/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="de-AT" rel="alternate"/>
#      <link href="https://www.tripadvisor.com.gr/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="el" rel="alternate"/>
#      <link href="https://www.tripadvisor.com.au/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="en-AU" rel="alternate"/>
#      <link href="https://www.tripadvisor.com.my/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="en-MY" rel="alternate"/>
#      <link href="https://www.tripadvisor.co.nz/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="en-NZ" rel="alternate"/>
#      <link href="https://www.tripadvisor.com.ph/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="en-PH" rel="alternate"/>
#      <link href="https://www.tripadvisor.com.sg/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="en-SG" rel="alternate"/>
#      <link href="https://www.tripadvisor.co.za/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="en-ZA" rel="alternate"/>
#      <link href="https://www.tripadvisor.com.ar/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="es-AR" rel="alternate"/>
#      <link href="https://www.tripadvisor.cl/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="es-CL" rel="alternate"/>
#      <link href="https://www.tripadvisor.co/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="es-CO" rel="alternate"/>
#      <link href="https://www.tripadvisor.com.pe/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="es-PE" rel="alternate"/>
#      <link href="https://www.tripadvisor.com.ve/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="es-VE" rel="alternate"/>
#      <link href="https://www.tripadvisor.fi/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="fi" rel="alternate"/>
#      <link href="https://www.tripadvisor.co.hu/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="hu" rel="alternate"/>
#      <link href="https://www.tripadvisor.co.id/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="id" rel="alternate"/>
#      <link href="https://www.tripadvisor.co.il/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="he" rel="alternate"/>
#      <link href="https://www.tripadvisor.co.kr/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="ko" rel="alternate"/>
#      <link href="https://no.tripadvisor.com/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="nb" rel="alternate"/>
#      <link href="https://pl.tripadvisor.com/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="pl" rel="alternate"/>
#      <link href="https://www.tripadvisor.pt/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="pt-PT" rel="alternate"/>
#      <link href="https://www.tripadvisor.ru/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="ru" rel="alternate"/>
#      <link href="https://www.tripadvisor.sk/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="sk" rel="alternate"/>
#      <link href="https://www.tripadvisor.rs/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="sr" rel="alternate"/>
#      <link href="https://th.tripadvisor.com/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="th" rel="alternate"/>
#      <link href="https://www.tripadvisor.com.vn/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="vi" rel="alternate"/>
#      <link href="https://www.tripadvisor.com.tw/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="zh-Hant" rel="alternate"/>
#      <link href="https://www.tripadvisor.ch/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="de-CH" rel="alternate"/>
#      <link href="https://fr.tripadvisor.ch/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="fr-CH" rel="alternate"/>
#      <link href="https://it.tripadvisor.ch/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="it-CH" rel="alternate"/>
#      <link href="https://en.tripadvisor.com.hk/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="en-HK" rel="alternate"/>
#      <link href="https://fr.tripadvisor.be/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="fr-BE" rel="alternate"/>
#      <link href="https://www.tripadvisor.be/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="nl-BE" rel="alternate"/>
#      <link href="https://www.tripadvisor.com.hk/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" hreflang="zh-hk" rel="alternate"/>
#      <meta content="TripAdvisor" property="al:ios:app_name"/>
#      <meta content="284876795" property="al:ios:app_store_id"/>
#      <meta content="284876795" name="twitter:app:id:ipad" property="twitter:app:id:ipad"/>
#      <meta content="284876795" name="twitter:app:id:iphone" property="twitter:app:id:iphone"/>
#      <meta content="tripadvisor://www.tripadvisor.com/Attraction_Review-g295424-d676922-Reviews-m33762-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" property="al:ios:url"/>
#      <meta content="tripadvisor://www.tripadvisor.com/Attraction_Review-g295424-d676922-Reviews-m33762-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" name="twitter:app:url:ipad" property="twitter:app:url:ipad"/>
#      <meta content="tripadvisor://www.tripadvisor.com/Attraction_Review-g295424-d676922-Reviews-m33762-Burj_Khalifa-Dubai_Emirate_of_Dubai.html" name="twitter:app:url:iphone" property="twitter:app:url:iphone"/>
#      <!--trkP:bot_detection-->
#      <!-- PLACEMENT bot_detection -->
#      <script type="text/javascript">
#       var taEarlyRoyBattyStatus = 0;var taSecureToken = "TNI1625!AI2dqWhQ1jV4WxKa7LBbJU+UqnK8c5UmcxtVbGflfgxjKby4iXkw9bCRHQdQAfX0yUdBTSjiYYQxYOwSJrWlq0k7PPdn2529w/AxrthTNIH9vrZLXwluGMzQAxW1DNHlPTBAZU+wG5I0wJkv6B0YdEIBkUeNy92AOPbYAFIvOlSh";(function() {var cookieDomain = ".tripadvisor.com";var sessionPartition = "-1";try {if (navigator.userAgent.indexOf('MSIE 10.0') < 0) {var val = taSecureToken+",1";val = encodeURIComponent(val);if (cookieDomain) {val += "; domain=" + cookieDomain;}document.cookie = "roybatty="+val+"; path=/";var url="/CookiePingback?early=true";var xhr = null;try {xhr = new XMLHttpRequest();} catch (e1) {try {xhr = new ActiveXObject('MSXML2.XMLHTTP');} catch (e2) {try {xhr = new ActiveXObject('Microsoft.XMLHTTP');} catch (e3) {}}}if (xhr != null) {var seth = function(name, val) {try {xhr.setRequestHeader(name, val)}catch(e){}};xhr.open("POST", url, true);seth('Content-type', 'application/x-www-form-urlencoded; charset=utf-8');seth('X-Requested-With', 'XMLHttpRequest');seth('Accept', 'text/javascript, text/html, application/xml, text/xml, */*');xhr.send('');taEarlyRoyBattyStatus = 2;}} } catch(err) {}})();
#      </script>
#      <!--etk-->
#      <link data-rup="location_detail_rebrand" href="https://static.tacdn.com/css2/location_detail_rebrand-v23980343832a.css" media="screen, print" rel="stylesheet" type="text/css"/>
#      <!--[if IE 6]>
#     <link rel="stylesheet" type="text/css" media="screen, print" href="https://static.tacdn.com/css2/winIE6-v2360877535a.css" />
#         <![endif]-->
#      <!--[if IE 7]>
#     <link rel="stylesheet" type="text/css" media="screen, print" href="https://static.tacdn.com/css2/winIE7-v22702072199a.css" />
#         <![endif]-->
#      <style type="text/css">
#       <!--
# DIV.ppr_rup.ppr_priv_unsupported_browser_messaging .unsupportedBrowser {
# padding: 5px;
# background-color: #f5f5f5;
# font-size: .75em;
# }
# DIV.ppr_rup.ppr_priv_unsupported_browser_messaging .unsupportedBrowser .innerDiv {
# padding: 6px 0 8px 79px;
# line-height: 167.5%;
# font-weight: bold;
# }
# DIV.ppr_rup.ppr_priv_unsupported_browser_messaging .ui_link {
# font-weight: normal;
# }
# -->
#      </style>
#      <style type="text/css">
#       <!--
# DIV.ppr_rup.ppr_priv_attraction_promo_header .attraction_promo_header {
# background-color: #f4f3f0;
# margin: 0 auto;
# padding: 10px 5px;
# text-align: center;
# font-size: 16px;
# }
# @media (min-width: 1024px) {
# DIV.ppr_rup.ppr_priv_attraction_promo_header .attraction_promo_header {
# min-width: 900px;
# }
# }
# @media (max-width: 767px) {
# DIV.ppr_rup.ppr_priv_attraction_promo_header .attraction_promo_header {
# display: -ms-flexbox;
# display: -webkit-box;
# display: -moz-box;
# display: -webkit-flex;
# display: flex;
# border: 1px solid #e26726;
# border-radius: 4px;
# margin: 5px;
# padding: 5px;
# }
# }
# DIV.ppr_rup.ppr_priv_attraction_promo_header .attraction_promo_header .block {
# display: inline-block;
# }
# DIV.ppr_rup.ppr_priv_attraction_promo_header .attraction_promo_header .savings_icon.ui_icon.special-offer-45deg {
# color: #00a680;
# font-size: 26px;
# position: relative;
# top: -6px;
# height: 23px;
# margin-right: 5px;
# vertical-align: text-top;
# }
# @media (max-width: 767px) {
# DIV.ppr_rup.ppr_priv_attraction_promo_header .attraction_promo_header .savings_icon.ui_icon.special-offer-45deg {
# display: none;
# }
# }
# DIV.ppr_rup.ppr_priv_attraction_promo_header .attraction_promo_header .discount {
# color: #e26726;
# font-weight: bold;
# }
# DIV.ppr_rup.ppr_priv_attraction_promo_header .attraction_promo_header .i_container {
# margin-left: 8px;
# }
# DIV.ppr_rup.ppr_priv_attraction_promo_header .attraction_promo_header .i_container .i_icon {
# top: 20px;
# width: 17px;
# height: 17px;
# border-radius: 10px;
# padding: 1px;
# font-size: 1em;
# font-weight: bold;
# text-align: center;
# border: 1px solid #777;
# color: #777;
# display: inline-block;
# line-height: normal;
# cursor: pointer;
# }
# -->
#      </style>
#      <style type="text/css">
#       <!--
# DIV.prw_rup.prw_common_flexible_thumb {
# height: 100%;
# }
# DIV.prw_rup.prw_common_flexible_thumb .imageThumbnail {
# position: relative;
# height: 100%;
# cursor: pointer;
# }
# -->
#      </style>
#      <style type="text/css">
#       <!--DIV.prw_rup.prw_common_centered_image {
# height: 100%;
# }
# DIV.prw_rup.prw_common_centered_image .imgWrap {
# display: block;
# position: relative;
# width: 100%;
# height: 100%;
# overflow: hidden;
# }
# DIV.prw_rup.prw_common_centered_image .imgWrap .centeredImg:not(.lte_ie8) {
# position: relative;
# top: 50%;
# left: 50%;
# transform: translate(-50%, -50%);
# -webkit-transform: translate(-50%, -50%);
# -moz-transform: translate(-50%, -50%);
# -ms-transform: translate(-50%, -50%);
# }
# .rtl DIV.prw_rup.prw_common_centered_image .imgWrap .centeredImg:not(.lte_ie8) {
# transform: translate(50%, -50%);
# -webkit-transform: translate(50%, -50%);
# -moz-transform: translate(50%, -50%);
# -ms-transform: translate(50%, -50%);
# }
# DIV.prw_rup.prw_common_centered_image .imgWrap .centeredImg:not(.lte_ie8).noscript {
# position: absolute;
# }
# DIV.prw_rup.prw_common_centered_image .imgWrap.fixedAspect {
# position: relative;
# height: 0;
# }
# DIV.prw_rup.prw_common_centered_image .imgWrap.fixedAspect .centeredImg {
# position: absolute;
# }
# -->
#      </style>
#      <style type="text/css">
#       <!--
# DIV.prw_rup.prw_common_mercury_photo_carousel {
# position: relative;
# height: 100%;
# background: rgba(0, 0, 0, 0.75);
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .carousel {
# height: 100%;
# white-space: nowrap;
# overflow: hidden;
# position: relative;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .carousel[data-pop-photo-viewer] {
# cursor: pointer;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .carousel_images {
# height: 100%;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .carousel[data-pop-photo-viewer] .carousel_images:after {
# content: "";
# position: absolute;
# top: 0;
# bottom: 0;
# left: 0;
# right: 0;
# background: rgba(255, 255, 255, 0);
# -webkit-transition: background 200ms linear;
# -moz-transition: background 200ms linear;
# -o-transition: background 200ms linear;
# -ms-transition: background 200ms linear;
# transition: background 200ms linear;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .carousel.hovered[data-pop-photo-viewer] .carousel_images:after {
# background: rgba(255, 255, 255, 0.1);
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .photo {
# width: 100%;
# height: 100%;
# background-size: 100% auto;
# background-repeat: no-repeat;
# background-position: 50% 50%;
# display: block;
# overflow: hidden;
# vertical-align: bottom;
# position: absolute;
# transition: all 500ms;
# opacity: 0;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .photo.portrait {
# background-size: auto 100%;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .photo.current {
# opacity: 1;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .left-nav:before,
# DIV.prw_rup.prw_common_mercury_photo_carousel .right-nav:before {
# position: absolute;
# content: "";
# top: -20px;
# bottom: -20px;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .left-nav:before {
# right: -20px;
# left: 0;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .right-nav:before {
# right: 0;
# left: -20px;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .left-nav,
# DIV.prw_rup.prw_common_mercury_photo_carousel .right-nav {
# position: absolute;
# z-index: 1;
# cursor: pointer;
# width: 40px;
# height: 40px;
# top: 50%;
# margin-top: -15px;
# background: rgba(0, 0, 0, 0.32);
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .left-nav:hover,
# DIV.prw_rup.prw_common_mercury_photo_carousel .right-nav:hover {
# background: rgba(0, 0, 0, 0.5);
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .bignav .left-nav,
# DIV.prw_rup.prw_common_mercury_photo_carousel .bignav .right-nav {
# height: 60px;
# width: 60px;
# margin-top: -30px;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .left-nav {
# border-radius: 0 3px 3px 0;
# left: 0;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .right-nav {
# border-radius: 3px 0 0 3px;
# right: 0;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .left-nav:after,
# DIV.prw_rup.prw_common_mercury_photo_carousel .right-nav:after {
# position: absolute;
# top: 50%;
# margin: -6px;
# width: 10px;
# height: 10px;
# border-style: solid;
# border-color: #ffffff;
# content: "";
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .right-nav:after {
# left: 44%;
# border-width: 0 3px 3px 0;
# -ms-transform: rotate(-45deg);
# -webkit-transform: rotate(-45deg);
# transform: rotate(-45deg);
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .left-nav:after {
# right: 44%;
# border-width: 0 0 3px 3px;
# -ms-transform: rotate(45deg);
# -webkit-transform: rotate(45deg);
# transform: rotate(45deg);
# }
# .rtl DIV.prw_rup.prw_common_mercury_photo_carousel .right-nav {
# border-radius: 0px 3px 3px 0px;
# }
# .rtl DIV.prw_rup.prw_common_mercury_photo_carousel .left-nav {
# border-radius: 3px 0px 0px 3px;
# }
# .rtl DIV.prw_rup.prw_common_mercury_photo_carousel .right-nav:after {
# -ms-transform: rotate(45deg);
# -webkit-transform: rotate(45deg);
# transform: rotate(45deg);
# }
# .rtl DIV.prw_rup.prw_common_mercury_photo_carousel .left-nav:after {
# -ms-transform: rotate(-45deg);
# -webkit-transform: rotate(-45deg);
# transform: rotate(-45deg);
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .entry_cta_wrap {
# position: absolute;
# top: 112px;
# bottom: 112px;
# left: 112px;
# right: 112px;
# z-index: 1;
# cursor: pointer;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .entry_cta {
# position: absolute;
# top: 50%;
# left: 50%;
# display: inline-block;
# height: 60px;
# line-height: 60px;
# padding: 0 18px;
# font-size: 20px;
# font-weight: normal;
# color: #ffffff;
# white-space: nowrap;
# vertical-align: middle;
# background: rgba(0, 0, 0, 0.32);
# border-radius: 3px;
# opacity: 0;
# -webkit-transition: opacity 200ms linear;
# -moz-transition: opacity 200ms linear;
# -o-transition: opacity 200ms linear;
# -ms-transition: opacity 200ms linear;
# transition: opacity 200ms linear;
# transform: translate(-50%, -50%);
# -webkit-transform: translate(-50%, -50%);
# -moz-transform: translate(-50%, -50%);
# -ms-transform: translate(-50%, -50%);
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .entry_cta:hover {
# background: rgba(0, 0, 0, 0.5);
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .entry_cta .ui_icon {
# position: relative;
# top: -2px;
# margin-right: 8px;
# font-size: 20px;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .carousel.hovered .entry_cta {
# opacity: 1;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .more-photos {
# z-index: 0;
# background: rgba(0, 0, 0, 0.75);
# color: white;
# display: flex;
# align-items: center;
# justify-content: center;
# background-repeat: no-repeat;
# background-position: 50% 50%;
# background-size: cover;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .more-photos.current {
# z-index: 1;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .more-photos:after {
# content: '';
# position: absolute;
# top: 0;
# left: 0;
# bottom: 0;
# right: 0;
# z-index: -1;
# background-color: rgba(0, 0, 0, 0.75);
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .albums {
# display: inline-block;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .more-text {
# font-size: 22px;
# margin-bottom: 20px;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .see_all_count_wrap {
# position: absolute;
# right: 0;
# left: 0;
# bottom: 0;
# text-align: left;
# background-color: transparent;
# background: -webkit-gradient(linear, left top, left bottom, from(transparent), to(rgba(0, 0, 0, 0.8)));
# background: -moz-linear-gradient(top, transparent 0%, rgba(0, 0, 0, 0.8) 100%);
# background: -o-linear-gradient(top, transparent 0%, rgba(0, 0, 0, 0.8) 100%);
# background: -ms-linear-gradient(top, transparent 0%, rgba(0, 0, 0, 0.8) 100%);
# background: linear-gradient(to bottom, transparent 0%, rgba(0, 0, 0, 0.8) 100%);
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .see_all_count_wrap .see_all_count {
# position: relative;
# display: inline-block;
# margin-top: 16px;
# padding: 16px;
# font-size: 16px;
# color: #ffffff;
# cursor: pointer;
# z-index: 1;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .see_all_count_wrap .see_all_count:hover {
# text-decoration: underline;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .see_all_count_wrap .ui_icon.camera {
# font-size: 18px;
# margin-right: 6px;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .add-photo {
# display: flex;
# flex-direction: column;
# justify-content: center;
# align-items: center;
# height: 100%;
# width: 100%;
# background: #f5f5f5;
# position: relative;
# text-decoration: none;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .cta-icon {
# position: relative;
# display: inline-block;
# margin-bottom: 10px;
# color: #e5e5e5;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .cta-icon .camera {
# font-size: 112px;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .badge-container {
# align-items: center;
# background: #ffffff;
# border-radius: 0 0 2px 2px;
# border-top: solid #00a680 1px;
# left: 20px;
# position: absolute;
# top: 0;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .tc-badge {
# display: flex;
# flex-direction: column;
# height: 60px;
# justify-content: center;
# padding: 8px;
# width: 60px;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .tc-badge .tcAward {
# width: 60px;
# height: 60px;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .tc-badge .tcAward.svg {
# height: 150px;
# width: auto;
# }
# .ui_overlay DIV.prw_rup.prw_common_mercury_photo_carousel {
# background: #FFF;
# max-width: 350px;
# }
# .ui_overlay DIV.prw_rup.prw_common_mercury_photo_carousel .title {
# color: #000a12;
# font-size: 20px;
# line-height: 24px;
# font-weight: bold;
# margin-bottom: 5px;
# }
# .ui_overlay DIV.prw_rup.prw_common_mercury_photo_carousel .text {
# color: #4a4a4a;
# font-size: 14px;
# line-height: 18px;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel.tcPopoverATF .learnMore {
# display: block;
# font-size: 14px;
# line-height: 18px;
# margin-top: 5px;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .coe-badge {
# display: -ms-flexbox;
# display: -webkit-box;
# display: -moz-box;
# display: -webkit-flex;
# display: flex;
# padding: 5px 8px;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .coe-badge .badgeText {
# border-bottom: 1px dotted transparent;
# color: #4a4a4a;
# cursor: pointer;
# display: inline-block;
# display: -ms-flexbox;
# display: -webkit-box;
# display: -moz-box;
# display: -webkit-flex;
# display: flex;
# -ms-flex-align: center;
# -webkit-box-align: center;
# -moz-box-align: center;
# -webkit-align-items: center;
# align-items: center;
# font-size: 12px;
# line-height: 16px;
# margin: 0 2px;
# vertical-align: middle;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .coe-badge .badgeText:hover {
# border-color: #4a4a4a;
# }
# DIV.prw_rup.prw_common_mercury_photo_carousel .coe-badge .certificate-of-excellence {
# display: inline-block;
# display: -ms-flexbox;
# display: -webkit-box;
# display: -moz-box;
# display: -webkit-flex;
# display: flex;
# -ms-flex-align: center;
# -webkit-box-align: center;
# -moz-box-align: center;
# -webkit-align-items: center;
# align-items: center;
# color: #00a680;
# font-size: 24px;
# vertical-align: middle;
# }
# -->
#      </style>
#      <style type="text/css">
#       <!--
# DIV.prw_rup.prw_common_tag_questions {
# font-size: 14px;
# }
# DIV.prw_rup.prw_common_tag_questions .questions {
# border: 1px solid #e5e5e5;
# border-radius: 2px;
# padding: 20px;
# text-align: center;
# }
# DIV.prw_rup.prw_common_tag_questions .questions .questionText {
# font-weight: bold;
# }
# DIV.prw_rup.prw_common_tag_questions .questions .questionText span {
# color: #00a680;
# }
# DIV.prw_rup.prw_common_tag_questions .questions .answer {
# color: #4a4a4a;
# margin-left: 20px;
# cursor: pointer;
# white-space: nowrap;
# }
# DIV.prw_rup.prw_common_tag_questions .questions .answer:hover {
# text-decoration: underline;
# }
# DIV.prw_rup.prw_common_tag_questions .questions .answer:hover .ui_icon {
# text-decoration: none;
# }
# DIV.prw_rup.prw_common_tag_questions .questions .answer .ui_icon {
# margin-right: 5px;
# color: #767676;
# }
# DIV.prw_rup.prw_common_tag_questions .questions .answer .ui_icon.checkbox-checked {
# color: #00a680;
# }
# -->
#      </style>
#      <style type="text/css">
#       <!--
# DIV.prw_rup.prw_common_location_description .description {
# font-size: 14px;
# line-height: 18px;
# }
# DIV.prw_rup.prw_common_location_description .description .more {
# float: right;
# cursor: pointer;
# padding-left: 5px;
# display: none;
# }
# DIV.prw_rup.prw_common_location_description .description .text {
# white-space: nowrap;
# text-overflow: ellipsis;
# overflow-x: auto;
# }
# DIV.prw_rup.prw_common_location_description .description.overflow .more {
# display: block;
# }
# DIV.prw_rup.prw_common_location_description .description.overflow .text {
# overflow-x: hidden;
# }
# -->
#      </style>
#      <style type="text/css">
#       <!--
# DIV.ppr_rup.ppr_priv_attraction_merchandising .card {
# background-color: #fff;
# border: 1px solid #e9e8e6;
# border-bottom-color: #dad7c8;
# -webkit-box-sizing: border-box;
# -moz-box-sizing: border-box;
# box-sizing: border-box;
# display: block;
# float: left;
# margin: 1.33%;
# padding: 166px 0 8px;
# position: relative;
# opacity: 1;
# transition: box-shadow linear 100ms;
# text-align: left;
# width: 22.66%;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .placement:not(.fewer_products) .card {
# width: 22.33%;
# }
# body:not(.tablet_desktop) DIV.ppr_rup.ppr_priv_attraction_merchandising .card:hover {
# box-shadow: 0 0 8px 0 rgba(0,0,0,0.4);
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .thumb {
# background: #eee; /* for no_image */
# cursor: pointer;
# height: 160px;
# left: 0px;
# line-height: 160px; /* for no_image */
# position: absolute;
# text-align: center; /* for no_image */
# top: 0px;
# transition: opacity 100ms linear;
# }
# body:not(.tablet_desktop) DIV.ppr_rup.ppr_priv_attraction_merchandising .card:hover .thumb {
# filter: alpha(opacity=90);
# opacity: .9;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .content_test_v2 .four_per_row .card {
# padding-top: 117px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .three_per_row .card {
# width: 31.11%;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .two_per_row .card {
# height: 162px;
# padding: 4px 0 16px 240px;
# width: 48%;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .fewer_products .card.first {
# margin-left: 0.66%;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .first_row .card {
# margin-top: 15px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .fewer_products .card.last {
# margin-right: 0.66%;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .last_row .card {
# margin-bottom: 15px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .cards_parent {
# text-align: justify;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .content:after {
# content: '';
# display: inline-block;
# font-size: 0;
# line-height: 0;
# width: 100%;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .desc {
# display: block;
# height: 72px;
# margin: 5px 16px 0;
# overflow: hidden;
# }
# .lang_ja DIV.ppr_rup.ppr_priv_attraction_merchandising .desc {
# height: 96px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .two_per_row .desc {
# height: 86px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .desc .short {
# height: 44px;
# }
# .lang_ja DIV.ppr_rup.ppr_priv_attraction_merchandising .desc .short {
# height: 60px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .duration {
# height: 17px;
# padding-top: 11px;
# }
# .lang_ja DIV.ppr_rup.ppr_priv_attraction_merchandising .two_per_row .duration {
# padding-top: 0;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .expand {
# margin-left: 10px;
# vertical-align: baseline;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising h2 {
# font-size: 21px;
# font-weight: normal;
# margin: 30px 0 24px 18px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .lessContent {
# bottom: 0;
# padding: 0 0 4px 0;
# position: absolute;
# text-align: center;
# width: 100%;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .moreContent {
# border-bottom: 4px solid #000;
# bottom: 0;
# position: absolute;
# text-align: center;
# width: 100%;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .placement {
# margin: 18px 0;
# position: relative;
# -webkit-font-smoothing: antialiased;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .placement:not(.fewer_products) {
# background-color: #fff;
# border: 1px solid #f0f0f0;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .placement.withFooter {
# padding-bottom: 21px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .price {
# background: #fec52e;
# box-shadow: 3px 3px 6px rgba(0,0,0,0.5);
# color: #2c2c2c;
# height: 21px;
# left: -8px;
# line-height: 21px;
# padding: 5px 8px;
# position: absolute;
# top: 10px;
# z-index: 1;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .price:after {
# border-color: #fec52e transparent transparent #fec52e;
# border-style: solid;
# border-width: 31px 10px 0 0;
# content: '';
# font-size: 14px;
# font-weight: bold;
# height: 0;
# position: absolute;
# right: -10px;
# top: 0;
# width: 0;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .price:before {
# border-color: #875f13 transparent;
# border-style: solid;
# border-width: 7px 0 0 7px;
# content: '';
# height: 0;
# left: 0;
# position: absolute;
# top: 100%;
# width: 0;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .price span {
# font-size: 20px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .price_test {
# float: right;
# font-size: 12px;
# height: 36px;
# padding-top: 12px;
# text-align: right;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .three_per_row .price_test {
# padding-top: 0;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .price_test span {
# font-size: 20px;
# font-weight: bold;
# text-align: right;
# display: block;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .product_details {
# margin: 5px 16px 0;
# }
# .lang_ja DIV.ppr_rup.ppr_priv_attraction_merchandising .product_details {
# height: 108px;
# }
# .lang_ja DIV.ppr_rup.ppr_priv_attraction_merchandising .three_per_row .product_details {
# height: 103px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .rating_and_reviews .button_inner {
# padding-left: 8px;
# padding-right: 8px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .rating_and_reviews .rating {
# margin-bottom: 6px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .rating_and_reviews .reviews {
# font-size: 12px;
# color: #999999;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .rating_container {
# display: inline-block;
# height: 37px;
# margin-top: 6px;
# width: 100%;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .three_per_row .rating_container {
# margin-top: 12px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .two_per_row .rating_container {
# margin-top: 37px;
# }
# .lang_ja DIV.ppr_rup.ppr_priv_attraction_merchandising .two_per_row .rating_container {
# margin-top: 21px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .rating_container .more_info {
# float: right;
# padding-top: 5px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .rating_container .rating_and_reviews {
# float: left;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .readMore {
# color: #069;
# cursor: pointer;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .seeLess {
# color: #069;
# cursor: pointer;
# font-size: 17px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .seeMore {
# background: #000;
# border-top-left-radius: 5px;
# border-top-right-radius: 5px;
# bottom: 4px;
# color: #fff;
# cursor: pointer;
# font-weight: bold;
# padding: 5px 16px;
# position: relative;
# }
# .lang_ja DIV.ppr_rup.ppr_priv_attraction_merchandising .seeMore {
# bottom: 2px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .thumb {
# background: #eee; /* for no_image */
# cursor: pointer;
# height: 160px;
# left: 0px;
# line-height: 160px; /* for no_image */
# position: absolute;
# text-align: center; /* for no_image */
# top: 0px;
# transition: opacity 100ms linear;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .content_test_v2 .four_per_row .thumb {
# height: 111px;
# line-height: 111px; /* for no_image */
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .cards_parent:not(.two_per_row) .thumb {
# width: 100%
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .thumbCrop {
# cursor: pointer;
# display: inline-block;
# height: 160px;
# overflow: hidden;
# width: 100%;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .content_test_v2 .four_per_row .thumbCrop {
# height: 111px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .thumbCrop img {
# height: 174px;
# margin-top: -7px;
# vertical-align: middle;
# width: 261px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .content_test_v2 .thumbCrop img {
# margin-top: -32px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .three_per_row .thumbCrop img {
# height: auto;
# margin-top: -40px;
# width: auto;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .two_per_row .thumbCrop img {
# height: 160px;
# margin-top: auto;
# width: 240px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .title {
# color: #069;
# cursor: pointer;
# display: block;
# font-size: 17px;
# font-weight: bold;
# height: 44px;
# margin: 5px 16px;
# overflow: hidden;
# }
# body:not(.tablet_desktop) DIV.ppr_rup.ppr_priv_attraction_merchandising .title:hover,
# body:not(.tablet_desktop) DIV.ppr_rup.ppr_priv_attraction_merchandising .title:focus {
# text-decoration: none;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .title span {
# vertical-align: middle;
# }
# body:not(.tablet_desktop) DIV.ppr_rup.ppr_priv_attraction_merchandising .title:hover .name,
# body:not(.tablet_desktop) DIV.ppr_rup.ppr_priv_attraction_merchandising .title:focus .name {
# text-decoration: underline;
# }
# .lang_ja DIV.ppr_rup.ppr_priv_attraction_merchandising .title {
# height: 55px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .titleBlock {
# margin-bottom: 8px;
# overflow: hidden;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .titleText {
# color: #4a4a4a;
# font-size: 21px;
# font-weight: normal;
# margin: 30px 0 24px 18px;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .title_test {
# color: #006699;
# cursor: pointer;
# float: left;
# font-size: 14px;
# font-weight: bold;
# height: 48px;
# overflow: hidden;
# width: 72%;
# }
# .lang_ja DIV.ppr_rup.ppr_priv_attraction_merchandising .title_test {
# height: 60px;
# width: 50%;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .three_per_row .title_test {
# font-size: 17px;
# height: 43px;
# }
# .lang_ja DIV.ppr_rup.ppr_priv_attraction_merchandising .three_per_row .title_test {
# width: 60%;
# }
# DIV.ppr_rup.ppr_priv_attraction_merchandising .two_per_row .title_test {
# font-size: 18px;
# height: 62px;
# }
# .lang_ja DIV.ppr_rup.ppr_priv_attraction_merchandising .three_per_row .title_test {
# height: 48px;
# }
# .lang_ja DIV.ppr_rup.ppr_priv_attraction_merchandising .two_per_row .title_test {
# height: 78px;
# }-->
#      </style>
#      <style type="text/css">
#       <!--
# DIV.prw_rup.prw_common_map_sponsorship .floating_sponsor {
# position: absolute;
# z-index: 1;
# right: 0;
# bottom: 20px;
# min-width: 115px;
# height: 32px;
# padding: 1px;
# background-color: rgba(255, 255, 255, 0.8);
# font-size: 11px;
# color: #4a4a4a;
# text-align: right;
# /* 2015 sponsors
# ---------------------------------------------------------------------------------------------- */
# }
# DIV.prw_rup.prw_common_map_sponsorship .floating_sponsor span {
# padding: 0 8px;
# line-height: 32px;
# }
# DIV.prw_rup.prw_common_map_sponsorship .floating_sponsor .sponsor_icon {
# display: inline-block;
# background-repeat: no-repeat;
# background-position: center;
# float: right;
# }
# DIV.prw_rup.prw_common_map_sponsorship .floating_sponsor .bstWst,
# DIV.prw_rup.prw_common_map_sponsorship .floating_sponsor .bstWstCa {
# width: 28px;
# height: 32px;
# background-image: url("/img2/maps/icons/logos/v2/2015/best_western_medium_2016.png");
# }
# DIV.prw_rup.prw_common_map_sponsorship .floating_sponsor .comfortinn,
# DIV.prw_rup.prw_common_map_sponsorship .floating_sponsor .comfortinnca,
# DIV.prw_rup.prw_common_map_sponsorship .floating_sponsor .comfortfamily {
# width: 28px;
# height: 32px;
# background-image: url("/img2/maps/icons/logos/v2/2015/comfort_medium.png");
# }
# DIV.prw_rup.prw_common_map_sponsorship .floating_sponsor .ramadaca {
# width: 42px;
# height: 32px;
# background-image: url("/img2/maps/icons/logos/v2/2015/ramada2_medium.png");
# }
# DIV.prw_rup.prw_common_map_sponsorship .floating_sponsor .qualityinn,
# DIV.prw_rup.prw_common_map_sponsorship .floating_sponsor .qualityinnca {
# width: 28px;
# height: 32px;
# background-image: url("/img2/maps/icons/logos/v2/2015/quality_inn_medium.png");
# }
# DIV.prw_rup.prw_common_map_sponsorship .floating_sponsor .hampton,
# DIV.prw_rup.prw_common_map_sponsorship .floating_sponsor .hamptonca {
# width: 28px;
# height: 32px;
# background-image: url("/img2/maps/icons/logos/v2/2015/hampton_inn_medium.png");
# }
# DIV.prw_rup.prw_common_map_sponsorship .floating_sponsor .sleepinn {
# width: 28px;
# height: 31px;
# background-image: url("/img2/maps/icons/logos/v2/2015/sleep_inn_2_medium.png");
# }
# -->
#      </style>
#      <style type="text/css">
#       <!--
# DIV.prw_rup.prw_hotels_special_message input.button-add {
# height: 32px;
# padding-left: 36px;
# padding-right: 10px;
# border: 1px solid #000000;
# background: #ff9900 url("http://placehold.it/16x16") no-repeat 10px center;
# cursor: pointer;
# }
# DIV.prw_rup.prw_hotels_special_message .xthrough_bad .strike_price {
# margin-bottom: 6px;
# font-family: Arial, Tahoma, "Bitstream Vera Sans", sans-serif;
# color: #d80007;
# font-size: 13px;
# position: relative;
# word-break: break-all;
# }
# DIV.prw_rup.prw_hotels_special_message .xthrough_bad .strike_price:after {
# border-top: 1px solid #d80007;
# content: "";
# position: absolute;
# left: 0;
# right: 0;
# top: 55%;
# }
# DIV.prw_rup.prw_hotels_special_message .xthrough_bad .ui_icon {
# font-size: 16px;
# margin-left: 4px;
# position: relative;
# bottom: 1px;
# color: #777777;
# }
# DIV.prw_rup.prw_hotels_special_message .specialMessageContainer {
# font-size: 14px;
# line-height: 14px;
# display: -webkit-flex;
# display: -ms-flexbox;
# display: -ms-flex;
# display: flex;
# -webkit-align-items: flex-start;
# -ms-align-items: flex-start;
# align-items: flex-start;
# padding: 16px 14px;
# border: 1px solid #d6d6d6;
# border-width: 1px 0;
# color: #ff6500;
# }
# DIV.prw_rup.prw_hotels_special_message .specialMessageContainer[data-messageType="TRAVEL_ALERT_CUBA"] {
# color: #d80007;
# }
# DIV.prw_rup.prw_hotels_special_message .specialMessageContainer.hidden {
# display: none;
# }
# DIV.prw_rup.prw_hotels_special_message .specialMessageContainer .messageIcon {
# -webkit-flex-shrink: 0;
# -ms-flex-shrink: 0;
# flex-shrink: 0;
# font-size: 24px;
# padding: 0 5px 0 0;
# }
# DIV.prw_rup.prw_hotels_special_message .specialMessageContainer .messageText {
# -webkit-flex-grow: 1;
# -ms-flex-grow: 1;
# flex-grow: 1;
# }
# DIV.prw_rup.prw_hotels_special_message .specialMessageContainer .messageText .primaryText {
# font-weight: bold;
# padding-right: 5px;
# }
# DIV.prw_rup.prw_hotels_special_message .specialMessageContainer .messageText .secondaryText {
# padding-right: 5px;
# }
# DIV.prw_rup.prw_hotels_special_message .specialMessageContainer .messageText .sAlertLinkClass {
# font-weight: normal;
# }
# DIV.prw_rup.prw_hotels_special_message .specialMessageContainer .messageText .moreInfo .moreText,
# DIV.prw_rup.prw_hotels_special_message .specialMessageContainer .messageText .moreInfo .lessText {
# text-decoration: underline;
# }
# DIV.prw_rup.prw_hotels_special_message .specialMessageContainer .messageText .moreInfo .contents {
# font-size: 12px;
# display: block;
# padding-top: 5px;
# }
# DIV.prw_rup.prw_hotels_special_message .specialMessageContainer .messageText .moreInfo:not(.collapsed) .moreText {
# display: none;
# }
# DIV.prw_rup.prw_hotels_special_message .specialMessageContainer .messageText .moreInfo.collapsed .contents,
# DIV.prw_rup.prw_hotels_special_message .specialMessageContainer .messageText .moreInfo.collapsed .lessText {
# display: none;
# }
# DIV.prw_rup.prw_hotels_special_message .specialMessageContainer .close {
# color: #4a4a4a;
# -webkit-flex-shrink: 0;
# -ms-flex-shrink: 0;
# flex-shrink: 0;
# font-size: 20px;
# cursor: pointer;
# }
# @media (min-width: 1024px), (min-width: 768px) {
# DIV.prw_rup.prw_hotels_special_message {
# max-height: 100px;
# opacity: 1;
# -webkit-transition: all 0.25s ease-in-out;
# -moz-transition: all 0.25s ease-in-out;
# -o-transition: all 0.25s ease-in-out;
# -ms-transition: all 0.25s ease-in-out;
# transition: all 0.25s ease-in-out;
# }
# DIV.prw_rup.prw_hotels_special_message.collapsed {
# max-height: 0;
# opacity: 0;
# }
# DIV.prw_rup.prw_hotels_special_message.collapsed .specialMessageContainer {
# margin: 0;
# }
# ...
# require(['ta/p13n/placements','ta/page','$prp/global_nav_links/handlers'], function(placements, impl) {
# window.ta.plc_global_nav_links_0_handlers = placements.load('global_nav_links','handlers.js', { 'name': 'global_nav_links', 'occurrence': 0, 'id': 'taplc_global_nav_links_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/global_nav_geopill/handlers'], function(placements, impl) {
# window.ta.plc_global_nav_geopill_0_handlers = placements.load('global_nav_geopill','handlers.js', { 'name': 'global_nav_geopill', 'occurrence': 0, 'id': 'taplc_global_nav_geopill_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["deferred/GeoSearch","handlers"], 'params': {"searchSessionId":"3884E68D3A965F8BD052FBAB472FE3A31507491391548ssid"}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/attraction_promo_header/handlers'], function(placements, impl) {
# window.ta.plc_attraction_promo_header_rebrand_0_handlers = placements.load('attraction_promo_header','handlers.js', { 'name': 'attraction_promo_header:rebrand', 'occurrence': 0, 'id': 'taplc_attraction_promo_header_rebrand_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/location_detail_header/handlers'], function(placements, impl) {
# window.ta.plc_location_detail_header_attractions_0_handlers = placements.load('location_detail_header','handlers.js', { 'name': 'location_detail_header:attractions', 'occurrence': 0, 'id': 'taplc_location_detail_header_attractions_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {"featAnimPortalUrl":"https://www.tripadvisor.com/blog/animal-welfare-education-portal/","isHotelReview":false,"animTrackingPageProperty":"Attractions","animTrackingPageActionPrefix":"Attraction_ReviewRedesign","animalAttraction":false}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/saves_cta_highlights/handlers'], function(placements, impl) {
# window.ta.plc_saves_cta_highlights_0_handlers = placements.load('saves_cta_highlights','handlers.js', { 'name': 'saves_cta_highlights', 'occurrence': 0, 'id': 'taplc_saves_cta_highlights_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/hsx_special_messaging/handlers'], function(placements, impl) {
# window.ta.plc_hsx_special_messaging_attractions_0_handlers = placements.load('hsx_special_messaging','handlers.js', { 'name': 'hsx_special_messaging:attractions', 'occurrence': 0, 'id': 'taplc_hsx_special_messaging_attractions_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/location_persistent_tabs_header/handlers'], function(placements, impl) {
# window.ta.plc_location_persistent_tabs_header_attraction_detail_0_handlers = placements.load('location_persistent_tabs_header','handlers.js', { 'name': 'location_persistent_tabs_header:attraction_detail', 'occurrence': 0, 'id': 'taplc_location_persistent_tabs_header_attraction_detail_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {"eventPrefix":"arrr"}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/location_detail_overview/handlers'], function(placements, impl) {
# window.ta.plc_location_detail_overview_attraction_0_handlers = placements.load('location_detail_overview','handlers.js', { 'name': 'location_detail_overview:attraction', 'occurrence': 0, 'id': 'taplc_location_detail_overview_attraction_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/waypoint_for_poi/handlers'], function(placements, impl) {
# window.ta.plc_waypoint_for_poi_1_handlers = placements.load('waypoint_for_poi','handlers.js', { 'name': 'waypoint_for_poi', 'occurrence': 1, 'id': 'taplc_waypoint_for_poi_1', 'location_id': 676922, 'servletName': 'Attraction_Review','servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/attraction_merchandising/handlers'], function(placements, impl) {
# window.ta.plc_attraction_merchandising_0_handlers = placements.load('attraction_merchandising','handlers.js', { 'name': 'attraction_merchandising', 'occurrence': 0, 'id': 'taplc_attraction_merchandising_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/location_detail_two_column/handlers'], function(placements, impl) {
# window.ta.plc_location_detail_two_column_top_0_handlers = placements.load('location_detail_two_column','handlers.js', { 'name': 'location_detail_two_column:top', 'occurrence': 0, 'id': 'taplc_location_detail_two_column_top_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/location_reviews_container/handlers'], function(placements, impl) {
# window.ta.plc_location_reviews_container_attractions_0_handlers = placements.load('location_reviews_container','handlers.js', { 'name': 'location_reviews_container:attractions', 'occurrence': 0, 'id': 'taplc_location_reviews_container_attractions_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/location_review_filter_controls/handlers'], function(placements, impl) {
# window.ta.plc_location_review_filter_controls_0_handlers = placements.load('location_review_filter_controls','handlers.js', { 'name': 'location_review_filter_controls', 'occurrence': 0, 'id': 'taplc_location_review_filter_controls_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/location_review_keyword_search/handlers'], function(placements, impl) {
# window.ta.plc_location_review_keyword_search_0_handlers = placements.load('location_review_keyword_search','handlers.js', { 'name': 'location_review_keyword_search', 'occurrence': 0, 'id': 'taplc_location_review_keyword_search_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/location_reviews_list/handlers'], function(placements, impl) {
# window.ta.plc_location_reviews_list_attractions_0_handlers = placements.load('location_reviews_list','handlers.js', { 'name': 'location_reviews_list:attractions', 'occurrence': 0, 'id': 'taplc_location_reviews_list_attractions_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/prodp13n_hr_sur_reviews_no_results/handlers'], function(placements, impl) {
# window.ta.plc_prodp13n_hr_sur_reviews_no_results_1_handlers = placements.load('prodp13n_hr_sur_reviews_no_results','handlers.js', { 'name': 'prodp13n_hr_sur_reviews_no_results', 'occurrence': 1, 'id': 'taplc_prodp13n_hr_sur_reviews_no_results_1', 'location_id': 676922, 'servletName': 'Attraction_Review','servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/location_detail_two_column/handlers'], function(placements, impl) {
# window.ta.plc_location_detail_two_column_bottom_0_handlers = placements.load('location_detail_two_column','handlers.js', { 'name': 'location_detail_two_column:bottom', 'occurrence': 0, 'id': 'taplc_location_detail_two_column_bottom_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/location_nearby/handlers'], function(placements, impl) {
# window.ta.plc_location_nearby_0_handlers = placements.load('location_nearby','handlers.js', { 'name': 'location_nearby', 'occurrence': 0, 'id': 'taplc_location_nearby_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["trcss!deferred/placement","handlers"], 'params': {"trackingName":"location_nearby_similar","noCommerce":true,"geoId":295424,"maxRequests":12,"geoPopIndexCount":1402}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/location_qa/handlers'], function(placements, impl) {
# window.ta.plc_location_qa_0_handlers = placements.load('location_qa','handlers.js', { 'name': 'location_qa', 'occurrence': 0, 'id': 'taplc_location_qa_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/browser_mode_tracking/handlers'], function(placements, impl) {
# window.ta.plc_browser_mode_tracking_0_handlers = placements.load('browser_mode_tracking','handlers.js', { 'name': 'browser_mode_tracking', 'occurrence': 0, 'id': 'taplc_browser_mode_tracking_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/global_footer/handlers'], function(placements, impl) {
# window.ta.plc_global_footer_0_handlers = placements.load('global_footer','handlers.js', { 'name': 'global_footer', 'occurrence': 0, 'id': 'taplc_global_footer_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/enable_cpm_content/handlers'], function(placements, impl) {
# window.ta.plc_enable_cpm_content_0_handlers = placements.load('enable_cpm_content','handlers.js', { 'name': 'enable_cpm_content', 'occurrence': 0, 'id': 'taplc_enable_cpm_content_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/maps_meta_block/handlers'], function(placements, impl) {
# window.ta.plc_maps_meta_block_0_handlers = placements.load('maps_meta_block','handlers.js', { 'name': 'maps_meta_block', 'occurrence': 0, 'id': 'taplc_maps_meta_block_0', 'location_id': 676922, 'servletClass': 'com.TripResearch.servlet.attraction.AttractionDetail', 'servletName': 'Attraction_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/prwidgets', 'ta/page'], function(prwidgets) {
# prwidgets.initWidgets(document);
# });
# /* ]]> */
#   </script>
#   <script crossorigin="anonymous" data-rup="long_lived_global_legacy" src="https://static.tacdn.com/js3/long_lived_global_legacy-c-v24294967295a.js" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" data-rup="short_lived_global_legacy" src="https://static.tacdn.com/js3/short_lived_global_legacy-c-v257405768a.js" type="text/javascript">
#   </script>
#   <div id="IP_IFRAME_HOLDER">
#   </div>
#  </body>
#  <!-- st: 588 dc: 0 sc: 33 -->
#  <!-- uid: Wdp@PgokL1MAAE33Zf8AAAAh -->
# </html>

# %%
print soup.title
# Out:
# <title>Burj Khalifa (Dubai, United Arab Emirates): Top Tips Before You Go (with Photos) - TripAdvisor</title>

# %%
def soupify(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')
    soup.prettify()
    return r, soup

# %%
r, soup = soupify("https://www.tripadvisor.com/Attraction_Review-g295424-d676922-Reviews-Burj_Khalifa-Dubai_Emirate_of_Dubai.html")

# %%
soup.title
# Out:
# <title>Burj Khalifa (Dubai, United Arab Emirates): Top Tips Before You Go (with Photos) - TripAdvisor</title>

# %% [markdown]
# # Request

# %%
r, soup = soupify("https://www.tripadvisor.com/Attractions-g293766-Activities-Botswana.html")

# %%
def rev_address(r, soup):
    r_links = []
    for a in soup.find_all('a','review_count'):
        r_links.append(a['href'])
    return r_links

# %%
r_links = rev_address(r,soup)

# %%
r_links[1]
# Out:
# u'/Attraction_Review-g316101-d553850-Reviews-Moremi_Wildlife_Reserve-Moremi_Game_Reserve_Okavango_Delta_North_West_District.html#REVIEWS'

# %%
r_links = []

for a in soup.find_all('a','review_count'):
    r_links.append(a['href'])
    print a['href']
# Out:
# /Attraction_Review-g317055-d1643251-Reviews-Okavango_Delta-Maun_North_West_District.html#REVIEWS
# /Attraction_Review-g316101-d553850-Reviews-Moremi_Wildlife_Reserve-Moremi_Game_Reserve_Okavango_Delta_North_West_District.html#REVIEWS
# /Attraction_Review-g297318-d12172119-Reviews-Chobe_National_Park-Kasane_North_West_District.html#REVIEWS
# /Attraction_Review-g472669-d478945-Reviews-Savute_Reserve-Chobe_National_Park_North_West_District.html#REVIEWS
# /Attraction_Review-g293767-d3396948-Reviews-Three_Chiefs_Statues-Gaborone_South_East_District.html#REVIEWS
# /Attraction_Review-g472673-d1171922-Reviews-Khwai_River_Bridge-Okavango_Delta_North_West_District.html#REVIEWS
# /Attraction_Review-g480161-d311243-Reviews-Tsodilo_Hills-Shakawe_North_West_District.html#REVIEWS
# /Attraction_Review-g293767-d3247057-Reviews-ISKCON_Gaborone-Gaborone_South_East_District.html#REVIEWS
# /Attraction_Review-g317055-d1643251-Reviews-Okavango_Delta-Maun_North_West_District.html#REVIEWS
# /Attraction_Review-g316101-d553850-Reviews-Moremi_Wildlife_Reserve-Moremi_Game_Reserve_Okavango_Delta_North_West_District.html#REVIEWS
# /Attraction_Review-g472669-d478945-Reviews-Savute_Reserve-Chobe_National_Park_North_West_District.html#REVIEWS
# /Attraction_Review-g472670-d3259396-Reviews-Makgadikgadi_Salt_Pan-Makgadikgadi_Pans_National_Park_Central_District.html#REVIEWS

# %%
r_links[1]
# Out:
# u'/Attraction_Review-g316101-d553850-Reviews-Moremi_Wildlife_Reserve-Moremi_Game_Reserve_Okavango_Delta_North_West_District.html#REVIEWS'

# %%
def format_url(r_links):
    base = 'http://www.tripadvisor.com{}'
    for i in range(len(r_links)):
        r_links[i] = base.format(r_links[i])
    return r_links

# %%
base = 'http://www.tripadvisor.com{}'
for i in range(len(r_links)):
    r_links[i] = base.format(r_links[i])

# %%
r_links
# Out:
# ['http://www.tripadvisor.com/Attraction_Review-g317055-d1643251-Reviews-Okavango_Delta-Maun_North_West_District.html#REVIEWS',
#  'http://www.tripadvisor.com/Attraction_Review-g316101-d553850-Reviews-Moremi_Wildlife_Reserve-Moremi_Game_Reserve_Okavango_Delta_North_West_District.html#REVIEWS',
#  'http://www.tripadvisor.com/Attraction_Review-g297318-d12172119-Reviews-Chobe_National_Park-Kasane_North_West_District.html#REVIEWS',
#  'http://www.tripadvisor.com/Attraction_Review-g472669-d478945-Reviews-Savute_Reserve-Chobe_National_Park_North_West_District.html#REVIEWS',
#  'http://www.tripadvisor.com/Attraction_Review-g293767-d3396948-Reviews-Three_Chiefs_Statues-Gaborone_South_East_District.html#REVIEWS',
#  'http://www.tripadvisor.com/Attraction_Review-g472673-d1171922-Reviews-Khwai_River_Bridge-Okavango_Delta_North_West_District.html#REVIEWS',
#  'http://www.tripadvisor.com/Attraction_Review-g480161-d311243-Reviews-Tsodilo_Hills-Shakawe_North_West_District.html#REVIEWS',
#  'http://www.tripadvisor.com/Attraction_Review-g293767-d3247057-Reviews-ISKCON_Gaborone-Gaborone_South_East_District.html#REVIEWS',
#  'http://www.tripadvisor.com/Attraction_Review-g317055-d1643251-Reviews-Okavango_Delta-Maun_North_West_District.html#REVIEWS',
#  'http://www.tripadvisor.com/Attraction_Review-g316101-d553850-Reviews-Moremi_Wildlife_Reserve-Moremi_Game_Reserve_Okavango_Delta_North_West_District.html#REVIEWS',
#  'http://www.tripadvisor.com/Attraction_Review-g472669-d478945-Reviews-Savute_Reserve-Chobe_National_Park_North_West_District.html#REVIEWS',
#  'http://www.tripadvisor.com/Attraction_Review-g472670-d3259396-Reviews-Makgadikgadi_Salt_Pan-Makgadikgadi_Pans_National_Park_Central_District.html#REVIEWS']

# %% [markdown]
# # scraping for reviews!

# %%
r_links[0]
# Out:
# 'http://www.tripadvisor.com/Attraction_Review-g317055-d1643251-Reviews-Okavango_Delta-Maun_North_West_District.html#REVIEWS'

# %%
r = requests.get(r_links[0],'html.parser')

# %%
soup = BeautifulSoup(r.content, 'html.parser')

# %%
soup.prettify()
# Out:
# u'<!DOCTYPE html>\n<html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="content-type"/>\n  <link data-rup="long_lived_global_legacy" href="https://static.tacdn.com/css2/long_lived_global_legacy-v24148336985a.css" rel="stylesheet" type="text/css"/>\n  <link href="https://static.tacdn.com/favicon.ico" id="favicon" rel="icon" type="image/x-icon"/>\n  <link as="font" crossorigin="" href="https://static.tacdn.com/css2/webfonts/TripAdvisor/TripAdvisor_Regular.woff2?v003.230" rel="preload" type="font/woff2"/>\n  <link color="#00a680" href="https://static.tacdn.com/img2/icons/ta_square.svg" rel="mask-icon" sizes="any">\n   <script data-rup="global_error" type="text/javascript">\n    !function(){function e(e,n,t,r,o,i){var a={error_script:n,line:t,column:r,ready_state:document.readyState};return u?void(require.defined("ta/util/Error")&&require("ta/util/Error").record(o,"error post load:: "+e,i,a,"ERROR",{isglobal:!0})):(s.push({msg:e||"",error:o,evt:i,data:a}),!window.IS_DEBUG)}function n(){require(["ta/util/Error"],function(e){for(;s.length;){var n=s.shift();n.msg.match(/(^|[^\\w.])ta .*defin/)||e.record(n.error,"window.onerror:: "+n.msg,n.evt,n.data,"ERROR",{isglobal:!0})}u=!0})}function t(){c=null,v=!1,a=d=null}function r(n,r,o,i,w,u){var s=u&&u.target;if(v){if((!a||w&&w.stack)&&(a=w),!l)try{l=arguments.callee}catch(e){}c?s=c:(!s||d&&s==window)&&(s=d),e(n,r,o,i,a,{target:s,callee:l}),t()}else{a=w,v=!0,d=s;try{l=arguments.callee}catch(e){}}}function o(e){e=e||window.event,r(e.message,e.filename,e.lineno,e.colno,e.error||e,e)}function i(e){e=e||window.event,c=e.target||e.srcElement,w&&clearTimeout(w),w=setTimeout(function(){w=0,c=null},1)}var a,d,c,l,w,u=!1,s=[],v=!1;window.onerror=function(e,n,t,o,i){return r(e,n,t,o,i,window.event),!window.IS_DEBUG},window.addEventListener?(window.addEventListener("error",o,!1),window.addEventListener("click",i,!0),window.addEventListener("load",n)):window.attachEvent&&(window.attachEvent("onerror",o),document.attachEvent("onmouseup",i),window.attachEvent("onload",n))}();!function(){var e,n,t=0,i=5e3;window.uiOverlay=function(o){document.readyState in{complete:1,loaded:1}?require(["ta/util/Error"],function(e){e.record("uiOverlay is missing from the rollup","",o)}):document.addEventListener&&(e=[].slice.call(arguments),t=(new Date).getTime(),n||(n=!0,document.addEventListener("DOMContentLoaded",function(){Date.now()-t<i&&uiOverlay.apply(null,e)},!1)))}}();\n   </script>\n   <script>\n    (function(w){\nvar q={d:[],r:[],c:[],t:[],v:[]};\nvar r = w.require = function() {q.r.push(arguments);};\nr.config = function() {q.c.push(arguments);};\nr.defined = r.specified = function() {return false;};\nr.taConfig = function() {q.t.push(arguments);};\nr.taVer = function(v) {q.v.push(v);};\nr.isQ=true;\nw.getRequireJSQueue = function() {return q;};\n})(window);\n   </script>\n   <script data-rup="amdearly" type="text/javascript">\n    !function(e){function t(e){return"function"==typeof require&&require.defined&&require.defined(e)}function n(e,t,n){t?e[t].apply(e,n):"function"==typeof e&&e.apply(e,n)}function r(){if(u=!0,require.isQ)throw"Fatal error - this page does not have require";if(e.getRequireJSQueue){for(var t=e.getRequireJSQueue();t.d.length>0;)define.apply(e,t.d.shift());for(;t.r.length>0;)require.apply(e,t.r.shift());e.getRequireJSQueue=null}l&&+new Date-i<5e3&&a.apply(e,l)}if(!e||!e.requireCallLast){var l,i,u=!1,a=e.requireCallLast=function(e,r){l=null;var a=[].slice.call(arguments,2);t(e)?n(require(e),r,a):t("trjs")?require(["trjs!"+e],function(e){n(e,r,a)}):u||(i=+new Date,l=[].slice.call(arguments))},c=e.requireCallIfReady=function(n){t(n)&&a.apply(e,arguments)},o=function(t,n,r,l){var i=c;return!r||"click"!==r.type&&"submit"!==r.type||(i=a,r.preventDefault&&r.preventDefault()),l.unshift(n),l.unshift(t),i.apply(e,l),!1};e.remoteModule=function(e,t){return o("remoteModule",null,e,[].slice.c ...

# %%
p_list = soup.find_all('p', 'partial_entry')

# %%
p_list[3]
# Out:
# <p class="partial_entry">We visited Okawango delta as a part of our overland tour. It was great place! But there were no fances to separate the camp from lions, elephants and any other animals and next morning we took bush walk. We saw fresh lion trails and two...<span class="taLnk ulBlueLinks" onclick="widgetEvCall('handlers.clickExpand',event,this);">More</span></p>

# %%
len(p_list)
# Out:
# 10

# %%
for i in range(len(p_list)):
    p_list[i] = p_list[i].string

# %%
p_list
# Out:
# [u'The diversity of the area has to be seen and experienced (you will not be disappointed), as it is truly nature (and Africa) at its best.\nIt will leave you wanting more, much more!!!',
#  None,
#  None,
#  None,
#  None,
#  u'Is a amazing experience! I did the airplane and the next day the helicopter and is speechless. I recommend this activities. Helicopter is more expensive but worth it!',
#  None,
#  u'fantastic sights, mokoro canoe definitely ideal for this, lots of animals close by and fabulous weather',
#  None,
#  None]

# %%
r_links[0]
# Out:
# 'http://www.tripadvisor.com/Attraction_Review-g317055-d1643251-Reviews-Okavango_Delta-Maun_North_West_District.html#REVIEWS'

# %%
ind = r_links[0].find('Reviews-')
ind
# Out:
# 62

# %%
link_new = r_links[0][:ind+8]+'or10-'+r_links[0][ind+8:]
print link_new
# Out:
# http://www.tripadvisor.com/Attraction_Review-g317055-d1643251-Reviews-or10-Okavango_Delta-Maun_North_West_District.html#REVIEWS

# %%
r = requests.get(link_new, 'html.parser')

# %%
soup = BeautifulSoup(r.content, 'html.parser')

# %%
soup.prettify()
# Out:
# u'<!DOCTYPE html>\n<html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="content-type"/>\n  <link data-rup="long_lived_global_legacy" href="https://static.tacdn.com/css2/long_lived_global_legacy-v24148336985a.css" rel="stylesheet" type="text/css"/>\n  <link href="https://static.tacdn.com/favicon.ico" id="favicon" rel="icon" type="image/x-icon"/>\n  <link as="font" crossorigin="" href="https://static.tacdn.com/css2/webfonts/TripAdvisor/TripAdvisor_Regular.woff2?v003.230" rel="preload" type="font/woff2"/>\n  <link color="#00a680" href="https://static.tacdn.com/img2/icons/ta_square.svg" rel="mask-icon" sizes="any">\n   <script data-rup="global_error" type="text/javascript">\n    !function(){function e(e,n,t,r,o,i){var a={error_script:n,line:t,column:r,ready_state:document.readyState};return u?void(require.defined("ta/util/Error")&&require("ta/util/Error").record(o,"error post load:: "+e,i,a,"ERROR",{isglobal:!0})):(s.push({msg:e||"",error:o,evt:i,data:a}),!window.IS_DEBUG)}function n(){require(["ta/util/Error"],function(e){for(;s.length;){var n=s.shift();n.msg.match(/(^|[^\\w.])ta .*defin/)||e.record(n.error,"window.onerror:: "+n.msg,n.evt,n.data,"ERROR",{isglobal:!0})}u=!0})}function t(){c=null,v=!1,a=d=null}function r(n,r,o,i,w,u){var s=u&&u.target;if(v){if((!a||w&&w.stack)&&(a=w),!l)try{l=arguments.callee}catch(e){}c?s=c:(!s||d&&s==window)&&(s=d),e(n,r,o,i,a,{target:s,callee:l}),t()}else{a=w,v=!0,d=s;try{l=arguments.callee}catch(e){}}}function o(e){e=e||window.event,r(e.message,e.filename,e.lineno,e.colno,e.error||e,e)}function i(e){e=e||window.event,c=e.target||e.srcElement,w&&clearTimeout(w),w=setTimeout(function(){w=0,c=null},1)}var a,d,c,l,w,u=!1,s=[],v=!1;window.onerror=function(e,n,t,o,i){return r(e,n,t,o,i,window.event),!window.IS_DEBUG},window.addEventListener?(window.addEventListener("error",o,!1),window.addEventListener("click",i,!0),window.addEventListener("load",n)):window.attachEvent&&(window.attachEvent("onerror",o),document.attachEvent("onmouseup",i),window.attachEvent("onload",n))}();!function(){var e,n,t=0,i=5e3;window.uiOverlay=function(o){document.readyState in{complete:1,loaded:1}?require(["ta/util/Error"],function(e){e.record("uiOverlay is missing from the rollup","",o)}):document.addEventListener&&(e=[].slice.call(arguments),t=(new Date).getTime(),n||(n=!0,document.addEventListener("DOMContentLoaded",function(){Date.now()-t<i&&uiOverlay.apply(null,e)},!1)))}}();\n   </script>\n   <script>\n    (function(w){\nvar q={d:[],r:[],c:[],t:[],v:[]};\nvar r = w.require = function() {q.r.push(arguments);};\nr.config = function() {q.c.push(arguments);};\nr.defined = r.specified = function() {return false;};\nr.taConfig = function() {q.t.push(arguments);};\nr.taVer = function(v) {q.v.push(v);};\nr.isQ=true;\nw.getRequireJSQueue = function() {return q;};\n})(window);\n   </script>\n   <script data-rup="amdearly" type="text/javascript">\n    !function(e){function t(e){return"function"==typeof require&&require.defined&&require.defined(e)}function n(e,t,n){t?e[t].apply(e,n):"function"==typeof e&&e.apply(e,n)}function r(){if(u=!0,require.isQ)throw"Fatal error - this page does not have require";if(e.getRequireJSQueue){for(var t=e.getRequireJSQueue();t.d.length>0;)define.apply(e,t.d.shift());for(;t.r.length>0;)require.apply(e,t.r.shift());e.getRequireJSQueue=null}l&&+new Date-i<5e3&&a.apply(e,l)}if(!e||!e.requireCallLast){var l,i,u=!1,a=e.requireCallLast=function(e,r){l=null;var a=[].slice.call(arguments,2);t(e)?n(require(e),r,a):t("trjs")?require(["trjs!"+e],function(e){n(e,r,a)}):u||(i=+new Date,l=[].slice.call(arguments))},c=e.requireCallIfReady=function(n){t(n)&&a.apply(e,arguments)},o=function(t,n,r,l){var i=c;return!r||"click"!==r.type&&"submit"!==r.type||(i=a,r.preventDefault&&r.preventDefault()),l.unshift(n),l.unshift(t),i.apply(e,l),!1};e.remoteModule=function(e,t){return o("remoteModule",null,e,[].slice.c ...

# %%
soup.find_all('p','partial_entry')
# Out:
# [<p class="partial_entry">This is the highlight of many, multi-day safaris and with good reason. In their winter, the animals are more likely to be seen by tourists and the climate is comfortable for hiking and other outdoor activities.</p>,
#  <p class="partial_entry">Never seen anything like this before. I went into delta area with a motor boat and two more tourists. The Delta is endless and terrain intimidating due to its sheer expanse, wilderness and no indications. If you lose way and go around you could finish...<span class="taLnk ulBlueLinks" onclick="widgetEvCall('handlers.clickExpand',event,this);">More</span></p>,
#  <p class="partial_entry">We visited the Okawango delta both from the air with a scenic flight and on the ground with mokoro and boat trips. The air view is astonishing. Awesome landscape. Full of animals. Also the water trips were very nice. The mokoro is a very relaxing...<span class="taLnk ulBlueLinks" onclick="widgetEvCall('handlers.clickExpand',event,this);">More</span></p>,
#  <p class="partial_entry">i loved it so much, traveling with Afro Trek Safaris was one of the great things i have ever did. that company is the best safaris and i do not hesitate to recommend Afro Trek safaris for you.;</p>,
#  <p class="partial_entry">One of the big, if not most well-known highlight of Botswana, you will have to do a Delta mokoro (boat) trip, a 45 minute scenic flight over the Delta and visit the adjacent Moremi game reserve.... If you have some money to spend, visit the...<span class="taLnk ulBlueLinks" onclick="widgetEvCall('handlers.clickExpand',event,this);">More</span></p>,
#  <p class="partial_entry">To see this wonder u need to visit 3 different camps for different climates The upper Okavango around Savute it can be lush it can be dry theres a pride which hunts lions there The middle Okavango the delta we stayed at Kugana Island Lodge...<span class="taLnk ulBlueLinks" onclick="widgetEvCall('handlers.clickExpand',event,this);">More</span></p>,
#  <p class="partial_entry">exciting, fantastic, amazing, magical, beautiful, challenging, awesome, adventure!\nsingle location On earth</p>,
#  <p class="partial_entry">We did a horse riding safari in the Delta with Okavango Horse Safaris who also do walking safaris. This was our second time and was even better than the first. So much wildlife. We had elephant in the camp. We saw leopard, lion, hippos and...<span class="taLnk ulBlueLinks" onclick="widgetEvCall('handlers.clickExpand',event,this);">More</span></p>,
#  <p class="partial_entry">Take the scenic flight , you are guaranteed to see many animals. What a view from your small plane as you are always close to the ground. It gets very busy so prebooking is a must</p>,
#  <p class="partial_entry">We did a safari with Overseas Adventure Travels to Zambia, Zimbabwe and Botswana. The entire trip was unbelievable and I would recommend doing the Okavango Delta and their other camps over Kenya and Tanzania.</p>]

# %% [markdown]
# # countries!

# %%
oceania = ['https://www.tripadvisor.com/Attractions-g255055-Activities-Australia.html',
          'https://www.tripadvisor.com/Attractions-g294338-Activities-French_Polynesia.html',
          'https://www.tripadvisor.com/Attractions-g255104-Activities-New_Zealand.html',
          'https://www.tripadvisor.com/Attractions-g294115-Activities-Papua_New_Guinea.html'
          ]

# %%
len(oceania)
# Out:
# 4

# %%
asia = ['https://www.tripadvisor.com/Attractions-g293939-Activities-Cambodia.html',
       'https://www.tripadvisor.com/Attractions-g294211-Activities-China.html',
       'https://www.tripadvisor.com/Attractions-g293860-Activities-India.html',
       'https://www.tripadvisor.com/Attractions-g294225-Activities-Indonesia.html',
       'https://www.tripadvisor.com/Attractions-g293977-Activities-Israel.html',
       'https://www.tripadvisor.com/Attractions-g294232-Activities-Japan.html',
       'https://www.tripadvisor.com/Attractions-g293951-Activities-Malaysia.html',
       'https://www.tripadvisor.com/Attractions-g293955-Activities-Mongolia.html',
       'https://www.tripadvisor.com/Attractions-g293889-Activities-Nepal.html',
       'https://www.tripadvisor.com/Attractions-g294006-Activities-Oman.html',
       'https://www.tripadvisor.com/Attractions-g294196-Activities-South_Korea.html',
       'https://www.tripadvisor.com/Attractions-g293915-Activities-Thailand.html',
       'https://www.tripadvisor.com/Attractions-g294012-Activities-United_Arab_Emirates.html'
       ]

# %%
len(asia)
# Out:
# 13

# %%
africa = ['https://www.tripadvisor.com/Attractions-g293717-Activities-Algeria.html',
         'https://www.tripadvisor.com/Attractions-g293762-Activities-Angola.html',
         'https://www.tripadvisor.com/Attractions-g293766-Activities-Botswana.html',
         'https://www.tripadvisor.com/Attractions-g294192-Activities-Cote_d_Ivoire.html',
         'https://www.tripadvisor.com/Attractions-g294200-Activities-Egypt.html',
         'https://www.tripadvisor.com/Attractions-g294206-Activities-Kenya.html',
         'https://www.tripadvisor.com/Attractions-g293804-Activities-Liberia.html',
         'https://www.tripadvisor.com/Attractions-g293808-Activities-Madagascar.html',
         'https://www.tripadvisor.com/Attractions-g293730-Activities-Morocco.html',
         'https://www.tripadvisor.com/Attractions-g293820-Activities-Namibia.html',
         'https://www.tripadvisor.com/Attractions-g293830-Activities-Senegal.html',
         'https://www.tripadvisor.com/Attractions-g293832-Activities-Sierra_Leone.html',
         'https://www.tripadvisor.com/Attractions-g293740-Activities-South_Africa.html',
         'https://www.tripadvisor.com/Attractions-g293747-Activities-Tanzania.html'
         ]
#possibly get rid of Liberia?

# %%
len(africa)
# Out:
# 14

# %%
sa = ['https://www.tripadvisor.com/Attractions-g294266-Activities-Argentina.html',
      'https://www.tripadvisor.com/Attractions-g294280-Activities-Brazil.html',
      'https://www.tripadvisor.com/Attractions-g294291-Activities-Chile.html',
      'https://www.tripadvisor.com/Attractions-g294311-Activities-Peru.html'
     ]

# %%
len(sa)
# Out:
# 4

# %%
na = ['https://www.tripadvisor.com/Attractions-g291959-Activities-Belize.html',
      'https://www.tripadvisor.com/Attractions-g153339-Activities-Canada.html',
      'https://www.tripadvisor.com/Attractions-g147364-Activities-Cayman_Islands.html',
      'https://www.tripadvisor.com/Attractions-g291982-Activities-Costa_Rica.html',
      'https://www.tripadvisor.com/Attractions-g147270-Activities-Cuba.html',
      'https://www.tripadvisor.com/Attractions-g147277-Activities-Curacao.html',
      'https://www.tripadvisor.com/Attractions-g295111-Activities-Greenland.html',
      'https://www.tripadvisor.com/Attractions-g147295-Activities-Grenada.html',
      'https://www.tripadvisor.com/Attractions-g292016-Activities-Honduras.html',
      'https://www.tripadvisor.com/Attractions-g150768-Activities-Mexico.html',
      'https://www.tripadvisor.com/Attractions-g294477-Activities-Nicaragua.html',
      'https://www.tripadvisor.com/Attractions-g294479-Activities-Panama.html',
      'https://www.tripadvisor.com/Attractions-g191-Activities-United_States.html'
     ]
#cuba?!
#big countries - US, CANADA

# %%
len(na)
# Out:
# 13

# %%
europe = ['https://www.tripadvisor.com/Attractions-g190410-Activities-Austria.html',
      'https://www.tripadvisor.com/Attractions-g294451-Activities-Bulgaria.html',
      'https://www.tripadvisor.com/Attractions-g274684-Activities-Czech_Republic.html',
      'https://www.tripadvisor.com/Attractions-g189512-Activities-Denmark.html',
      'https://www.tripadvisor.com/Attractions-g274952-Activities-Estonia.html',
      'https://www.tripadvisor.com/Attractions-g189896-Activities-Finland.html',
      'https://www.tripadvisor.com/Attractions-g187070-Activities-France.html',
      'https://www.tripadvisor.com/Attractions-g187275-Activities-Germany.html',
      'https://www.tripadvisor.com/Attractions-g189398-Activities-Greece.html',
      'https://www.tripadvisor.com/Attractions-g274881-Activities-Hungary.html',
      'https://www.tripadvisor.com/Attractions-g189952-Activities-Iceland.html',
      'https://www.tripadvisor.com/Attractions-g187768-Activities-Italy.html',
      'https://www.tripadvisor.com/Attractions-g190455-Activities-Norway.html',
      'https://www.tripadvisor.com/Attractions-g189100-Activities-Portugal.html',
      'https://www.tripadvisor.com/Attractions-g294457-Activities-Romania.html',
      'https://www.tripadvisor.com/Attractions-g294459-Activities-Russia.html',
      'https://www.tripadvisor.com/Attractions-g294471-Activities-Serbia.html',
      'https://www.tripadvisor.com/Attractions-g187427-Activities-Spain.html',
      'https://www.tripadvisor.com/Attractions-g189806-Activities-Sweden.html',
      'https://www.tripadvisor.com/Attractions-g293969-Activities-Turkey.html',
      'https://www.tripadvisor.com/Attractions-g186216-Activities-United_Kingdom.html'
     ]

# %%
len(europe)
# Out:
# 21

# %% [markdown]
# so far, the countries included for this project is shown in the image below:
# ![Countries](amCharts.png)
